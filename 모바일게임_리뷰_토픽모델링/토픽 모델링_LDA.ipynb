# %% [markdown]
# # 모바일 게임 리뷰 토픽 모델링

# %% [markdown]
# ## 분석 대상
# : 블루아카이브, 니케, 원신, 붕괴:스타레일
#
# ### 토픽 모델링 기법
# - LDA
# - KeyBERT
# - CTM(BERT-base)
# - BERTopic

# %% [markdown]
# ## 공통 전처리
#
# - 접속사 제거
# - 조사 제거
# - 한글,숫자 제외 텍스트 제거

# %%
import re
import pandas as pd
from soynlp.normalizer import repeat_normalize

# %%
with open('./data/stopwords_post_position.txt', 'r') as f:
    josa_lst = f.readlines()

with open('./data/stopword_conjunction.txt', 'r') as f:
    conjunction_lst = f.readline().split(', ')

# 불용어 처리
stopwords_pPosition = []
for josa in josa_lst:
    josa = re.sub('\n|\t', '', josa)
    if '/' in josa:
        josa_words = josa.split('/')
    else:
        josa_words = [josa]

    [stopwords_pPosition.append(word) for word in josa_words]

# %%
def pp_stopwords_pposition(txt, stopwords = stopwords_pPosition):
    
    split_words = txt.split()

    result = []
    for word in split_words:
        for length in range(max(map(len, stopwords)),0 , -1):
            if word[-length:] in stopwords:
                result.append(word[:-length])
                break
            elif length == 1:
                result.append(word)

    result = ' '.join(result)

    return result



def pp_stopwords_conjunction(txt, stopwords = conjunction_lst):
    for stopword in stopwords:
        if stopword in txt:

            # Stopword의 위치 찾기
            check_before_idx = re.search(stopword, txt).start() -1
            check_after_idx = re.search(stopword, txt).end() # idx가 아니라 번째 개념으로 자동으로 +1 되어있음

            # 시작위치가 첫번째일떄 예외처리
            if check_before_idx == -1:
                check_before_blank = True
            else:
                check_before_blank = True if txt[check_before_idx] == ' ' else False
            
            #종료지점이 끝위치일떄 예외처리
            if check_after_idx == len(txt):
                check_after_blank = True
            else:
                check_after_blank = True if txt[check_after_idx] == ' ' else False
            
            if check_before_blank and check_after_blank:
                txt = re.sub(stopword, ' ', txt).strip()
        
    return txt

def del_stopwords(txt):
    txt = pp_stopwords_conjunction(txt) # 접속사 제거
    txt = pp_stopwords_pposition(txt) # 조사 제거
    txt = re.sub('[^가-힣]', ' ', txt).strip() # 한글 제외 제거
    txt = repeat_normalize(txt, num_repeats=3)

    return txt

data = pd.read_csv('./data/reivews_df_preprocssing_ver.csv')
data['content'] = data['content'].apply(del_stopwords)

# %%
data = pd.read_csv('./data/reivews_df_preprocssing_ver.csv')
data['content'] = data['content'].apply(del_stopwords)

# %% [markdown]
# ## LDA
#
# 상위 1,000개의 단어로 LDA진행

# %%
from konlpy.tag import Okt, Mecab
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import LatentDirichletAllocation as LDA

mecab = Mecab()
okt = Okt()

# %%
review_content = data['content']
review_token_mecab = review_content.apply(mecab.nouns)
review_token_okt = review_content.apply(okt.pos)

def okt_token_div(tagging_lst):
    return [word[0] for word in tagging_lst if word[1] == 'Noun']

review_token_okt = review_token_okt = review_token_okt.apply(okt_token_div)

# %%
stopwords = ['도', '는', '다', '의', '가', '이', '은', '한', '에', '하', '고', '을', '를', '인', '듯',
              '과', '와', '네', '들', '듯', '지', '임', '게', '만', '되', '음', '면']

review_token_mecab = review_token_mecab.apply(lambda x: [item for item in x if item not in stopwords])
review_token_okt = review_token_okt.apply(lambda x: [item for item in x if item not in stopwords])

# %%
detokenized_mecab = []
detokenized_okt = []


for i in range(len(review_content)):
    t1 = ' '.join(review_token_mecab[i])
    t2 = ' '.join(review_token_okt[i])

    detokenized_mecab.append(t1)
    detokenized_okt.append(t2)

# %%
# Tfidf
vectorizer_m = TfidfVectorizer(max_features=1000)
vectorizer_o = TfidfVectorizer(max_features=1000)

X_1 = vectorizer_m.fit_transform(detokenized_mecab)
X_2 = vectorizer_o.fit_transform(detokenized_okt)

# %%
# LDA 모델링
lda_model_1 = LDA(n_components=30, learning_method='online', random_state=777, max_iter=1)
lda_model_1.fit_transform(X_1)

lda_model_2 = LDA(n_components=30, learning_method='online', random_state=777, max_iter=1)
lda_model_2.fit_transform(X_2)
# Out:
# array([[0.00709613, 0.00709613, 0.00709613, ..., 0.00709613, 0.00709613,
#         0.00709613],
#        [0.01427196, 0.01427196, 0.01427196, ..., 0.01427196, 0.01427196,
#         0.01427196],
#        [0.03333333, 0.03333333, 0.03333333, ..., 0.03333333, 0.03333333,
#         0.03333333],
#        ...,
#        [0.03333333, 0.03333333, 0.03333333, ..., 0.03333333, 0.03333333,
#         0.03333333],
#        [0.01666667, 0.01666667, 0.01666667, ..., 0.01666667, 0.01666667,
#         0.01666667],
#        [0.01666667, 0.01666667, 0.01666667, ..., 0.01666667, 0.01666667,
#         0.01666667]])

# %%
# 결과 확인
terms_m = vectorizer_m.get_feature_names_out()
terms_o = vectorizer_o.get_feature_names_out()

def get_topics(components, feature_names, n=5): 
    for idx, topic in enumerate(components):
        print("Topic %d:" % (idx+1), [(feature_names[i], topic[i].round(2)) for i in topic.argsort()[:-n - 1:-1]])

# %%
# LDA - Topics (Mecab)
get_topics(lda_model_1.components_,terms_m)
# Out:
# Topic 1: [('스마트폰', 843.31), ('게임', 175.54), ('다음', 137.63), ('어디', 120.49), ('이야기', 111.34)]
# Topic 2: [('백도어', 585.76), ('개발', 427.99), ('스타', 372.62), ('출시', 270.12), ('게임', 227.46)]
# Topic 3: [('번역', 3314.37), ('최고', 685.93), ('게임', 324.19), ('업체', 289.25), ('처음', 205.5)]
# Topic 4: [('업데이트', 451.26), ('오류', 332.61), ('데이터', 146.94), ('명작', 71.82), ('고치', 67.57)]
# Topic 5: [('개꿀', 317.9), ('배터리', 120.75), ('주기', 69.29), ('조아', 66.39), ('자기', 62.66)]
# Topic 6: [('소리', 287.03), ('필요', 280.96), ('신경', 194.62), ('내용', 169.53), ('사운드', 118.39)]
# Topic 7: [('확률', 367.08), ('이상', 353.04), ('조작', 303.22), ('가능', 150.08), ('얼마', 114.23)]
# Topic 8: [('자체', 212.12), ('번역기', 183.62), ('기분', 84.12), ('울트라', 73.39), ('우리', 67.8)]
# Topic 9: [('스킵', 519.77), ('시간', 488.78), ('개인', 372.44), ('자동', 256.26), ('게임', 231.36)]
# Topic 10: [('표절', 450.08), ('이게', 429.87), ('정보', 417.01), ('이해', 400.58), ('삭제', 309.41)]
# Topic 11: [('감사', 237.94), ('제발', 122.15), ('오랜만', 111.29), ('경험', 75.97), ('요즘', 51.27)]
# Topic 12: [('시작', 320.14), ('사람', 297.59), ('진행', 220.63), ('게임', 185.69), ('모험', 178.21)]
# Topic 13: [('중국', 443.98), ('콘솔', 142.06), ('게임', 110.83), ('지원', 105.28), ('음성', 56.77)]
# Topic 14: [('개선', 264.72), ('플레이', 216.73), ('중간', 173.98), ('주년', 172.66), ('노트', 120.63)]
# Topic 15: [('게임', 2756.2), ('인생', 256.58), ('쓰레기', 215.72), ('최악', 200.24), ('의미', 69.67)]
# Topic 16: [('버스', 415.93), ('접속', 262.34), ('별점', 186.05), ('튜토리얼', 82.55), ('몬스터', 78.16)]
# Topic 17: [('발열', 556.81), ('이거', 426.34), ('컨텐츠', 388.08), ('레일', 378.99), ('생각', 326.1)]
# Topic 18: [('꼬라지', 80.47), ('숨결', 58.67), ('아쉬움', 52.96), ('행복', 47.46), ('차이', 47.07)]
# Topic 19: [('사랑', 183.26), ('매력', 81.72), ('세계관', 76.39), ('피드백', 73.59), ('등등', 73.57)]
# Topic 20: [('붕괴', 680.37), ('초반', 255.5), ('때문', 164.38), ('시스템', 131.51), ('리세', 120.54)]
# Topic 21: [('영상', 329.54), ('수정', 262.64), ('광고', 241.85), ('현질', 219.82), ('한국어', 209.11)]
# Topic 22: [('과금', 321.81), ('장난', 91.0), ('무엇', 63.63), ('게임', 49.18), ('개발자', 37.77)]
# Topic 23: [('전설', 198.47), ('젤다', 186.88), ('한국', 179.3), ('짝퉁', 96.8), ('유출', 77.85)]
# Topic 24: [('원신', 1290.45), ('재미', 1015.93), ('그래픽', 931.07), ('기대', 809.68), ('게임', 343.26)]
# Topic 25: [('캐릭터', 373.43), ('몰입', 222.27), ('이것', 137.31), ('호불호', 94.35), ('작품', 60.62)]
# Topic 26: [('호요', 440.83), ('용량', 363.54), ('추천', 306.67), ('로그인', 292.3), ('다운', 257.98)]
# Topic 27: [('스토리', 836.06), ('정도', 246.13), ('퀘스트', 192.23), ('하나', 172.69), ('나름', 143.81)]
# Topic 28: [('최적', 360.15), ('화면', 227.33), ('최적화', 222.66), ('이건', 216.2), ('문제', 204.02)]
# Topic 29: [('오역', 1272.31), ('하루', 127.99), ('주세요', 59.99), ('완전', 53.86), ('파티', 48.47)]
# Topic 30: [('게임', 731.85), ('퀄리티', 582.71), ('스토리', 494.95), ('캐릭터', 411.61), ('번역', 350.22)]

# %%
# LDA - Topics (Okt)
get_topics(lda_model_2.components_,terms_o)
# Out:
# Topic 1: [('모험', 174.91), ('인생게임', 166.26), ('컨트롤', 126.01), ('하나', 119.42), ('간만', 91.29)]
# Topic 2: [('스토리', 613.45), ('레일', 377.99), ('스타', 363.0), ('개발', 358.1), ('업데이트', 334.0)]
# Topic 3: [('초반', 274.48), ('사운드', 131.1), ('지지', 59.47), ('시진핑', 33.8), ('만세', 23.35)]
# Topic 4: [('재밋음', 103.6), ('잼남', 72.25), ('플스', 62.38), ('여러분', 58.84), ('바람', 55.36)]
# Topic 5: [('퀄리티', 489.82), ('수준', 347.1), ('오픈월드', 198.98), ('자유도', 164.52), ('단점', 113.63)]
# Topic 6: [('콘솔', 138.11), ('어디', 95.1), ('기분', 80.24), ('인정', 71.62), ('차라리', 62.82)]
# Topic 7: [('뽑기', 517.15), ('제발', 457.84), ('확률', 322.96), ('조작', 284.89), ('삭제', 238.9)]
# Topic 8: [('처음', 262.4), ('진행', 242.21), ('이상', 168.55), ('엉망', 167.29), ('실망', 133.68)]
# Topic 9: [('그래픽', 914.31), ('젤다', 576.46), ('게임', 390.51), ('플레이', 290.49), ('정도', 266.0)]
# Topic 10: [('꿀잼', 444.98), ('로딩', 163.92), ('고치', 150.79), ('다시', 126.79), ('굿굿', 110.34)]
# Topic 11: [('진짜', 759.74), ('노잼', 220.75), ('사랑', 181.12), ('게임', 92.78), ('여기', 86.15)]
# Topic 12: [('존잼', 125.55), ('만족', 108.75), ('좀더', 80.19), ('울트라', 73.14), ('음식', 42.36)]
# Topic 13: [('백도어', 595.85), ('계속', 400.24), ('이해', 389.08), ('문제', 310.4), ('게임', 290.37)]
# Topic 14: [('번역', 3608.75), ('오역', 1258.65), ('게임', 547.31), ('그냥', 502.08), ('중국', 396.96)]
# Topic 15: [('시작', 248.73), ('소리', 236.35), ('개판', 236.3), ('화면', 177.48), ('상태', 168.39)]
# Topic 16: [('컨텐츠', 344.12), ('심해', 149.88), ('보상', 144.89), ('다른', 127.83), ('코드', 79.2)]
# Topic 17: [('버스', 462.91), ('표절', 429.73), ('지금', 182.43), ('한번', 182.25), ('접속', 146.66)]
# Topic 18: [('정말', 485.97), ('기대', 380.7), ('자꾸', 223.52), ('쓰레기', 213.77), ('리뷰', 202.41)]
# Topic 19: [('시간', 458.15), ('중간', 231.54), ('회사', 190.54), ('갑자기', 116.26), ('프로그램', 112.66)]
# Topic 20: [('붕괴', 662.91), ('최적화', 468.83), ('때문', 190.95), ('무슨', 121.32), ('다음', 115.86)]
# Topic 21: [('게임', 2512.18), ('스마트폰', 502.5), ('개인정보', 362.13), ('용량', 356.56), ('공간', 162.83)]
# Topic 22: [('스킵', 501.01), ('영상', 311.98), ('사람', 218.73), ('최악', 196.65), ('완전', 183.16)]
# Topic 23: [('발열', 528.53), ('느낌', 233.83), ('전설', 134.44), ('배터리', 116.77), ('한국', 93.99)]
# Topic 24: [('게임', 463.86), ('스토리', 363.17), ('캐릭터', 340.59), ('일단', 335.56), ('전투', 326.04)]
# Topic 25: [('캐릭터', 307.73), ('다운', 267.93), ('오류', 179.01), ('취향', 154.87), ('혼자', 72.31)]
# Topic 26: [('하라', 109.0), ('최고다', 74.56), ('우리', 73.6), ('여캐', 53.01), ('달라', 50.45)]
# Topic 27: [('게임', 342.02), ('생각', 293.35), ('현질', 207.91), ('자체', 189.78), ('나름', 142.38)]
# Topic 28: [('추천', 294.35), ('역시', 294.28), ('조금', 249.14), ('자동', 221.83), ('이건', 219.13)]
# Topic 29: [('이슈', 154.25), ('대체', 106.9), ('무기', 79.18), ('공격', 76.18), ('이름', 73.73)]
# Topic 30: [('재미', 846.34), ('턴제', 741.73), ('최고', 611.85), ('게임', 192.83), ('인생', 107.36)]

# %% [markdown]
# #### 게임별 토픽

# %%
class custom_LDA():
    def __init__(self, content):
        self.content = content
        self.mecab = Mecab()
        self.okt = Okt()
        self.preprocessing()
    
    def preprocessing(self, n_features = 1000):
        review_token_mecab = self.content.apply(self.mecab.nouns)
        review_token_okt = self.content.apply(self.okt.pos)
        def okt_token_div(tagging_lst):
            return [word[0] for word in tagging_lst if word[1] == 'Noun']

        review_token_okt = review_token_okt.apply(okt_token_div)

        stopwords = ['도', '는', '다', '의', '가', '이', '은', '한', '에', '하', '고', '을', '를', '인', '듯',
              '과', '와', '네', '들', '듯', '지', '임', '게', '만', '되', '음', '면']

        review_token_mecab = review_token_mecab.apply(lambda x: [item for item in x if item not in stopwords])
        review_token_okt = review_token_okt.apply(lambda x: [item for item in x if item not in stopwords])

        self.detokenized_mecab = []
        self.detokenized_okt = []

        for i in range(len(self.content)):
            t1 = ' '.join(review_token_mecab[i])
            t2 = ' '.join(review_token_okt[i])

            self.detokenized_mecab.append(t1)
            self.detokenized_okt.append(t2)

        # Tfidf
        self.vectorizer_mecab = TfidfVectorizer(max_features=n_features)
        self.vectorizer_okt = TfidfVectorizer(max_features=n_features)

        self.modeling()
        
    def modeling(self):
        X_1 = self.vectorizer_mecab.fit_transform(self.detokenized_mecab)
        X_2 = self.vectorizer_okt.fit_transform(self.detokenized_okt)

        # LDA 모델링
        lda_model_1 = LDA(n_components=30, learning_method='online', random_state=777, max_iter=1)
        lda_model_1.fit_transform(X_1)
        self.lda_model_1_components = lda_model_1.components_

        lda_model_2 = LDA(n_components=30, learning_method='online', random_state=777, max_iter=1)
        lda_model_2.fit_transform(X_2)
        self.lda_model_2_components = lda_model_2.components_

        self.terms_mecab = vectorizer_m.get_feature_names_out()
        self.terms_okt = vectorizer_o.get_feature_names_out()

    def get_topics(self, tagger, keyword_num=5): 
        if tagger == 0:
            components = self.lda_model_1_components
            feature_names = self.terms_mecab
        elif tagger == 1:
            components = self.lda_model_2_components
            feature_names = self.terms_okt

        for idx, topic in enumerate(components):
            print("Topic %d:" % (idx+1), [(feature_names[i], topic[i].round(2)) for i in topic.argsort()[:-keyword_num - 1:-1]])

# %%
# b_a : 블루아카이브 / n_k : 니케 / o_g : 원신 / d_s : 붕괴:스타레일

b_a = data[data['app_name'] == '블루아카이브'].reset_index()['content']
n_k = data[data['app_name'] == '니케'].reset_index()['content']
o_g = data[data['app_name'] == '원신'].reset_index()['content']
d_s = data[data['app_name'] == '붕괴:스타레일'].reset_index()['content']

# %%
b_a_LDA = custom_LDA(b_a)
n_k_LDA = custom_LDA(n_k)
o_g_LDA = custom_LDA(o_g)
d_s_LDA = custom_LDA(d_s)

# %%
print('::: Topics - Mecab :::')
b_a_LDA.get_topics(0, keyword_num = 5)
print()
print('::: Topics - Okt :::')
b_a_LDA.get_topics(1, keyword_num= 5)
print()
# Out:
# ::: Topics - Mecab :::
# Topic 1: [('확률', 19.02), ('없음', 17.33), ('인터페이스', 10.75), ('아쉬움', 3.89), ('가요', 2.98)]
# Topic 2: [('여러분', 49.93), ('상품', 43.02), ('절대', 32.41), ('제작자', 26.56), ('자연', 22.94)]
# Topic 3: [('최소', 57.87), ('상담', 23.1), ('기종', 15.37), ('선정', 13.86), ('이걸', 12.65)]
# Topic 4: [('방송', 141.31), ('접속', 43.78), ('숨결', 20.02), ('파악', 16.01), ('오역', 13.83)]
# Topic 5: [('개돼지', 281.72), ('상당', 41.58), ('방랑자', 38.91), ('검열', 31.32), ('우분', 16.63)]
# Topic 6: [('상자', 36.01), ('오랜만', 16.47), ('분위기', 15.92), ('구글', 13.22), ('보이', 12.46)]
# Topic 7: [('홍보', 188.21), ('리소스', 121.28), ('상품', 74.08), ('조합', 44.21), ('공개', 40.43)]
# Topic 8: [('강제', 24.89), ('버튜', 14.43), ('번역기', 11.13), ('별점', 3.69), ('엉망', 1.85)]
# Topic 9: [('최적', 29.24), ('시야', 26.11), ('환경', 14.65), ('상성', 11.38), ('개추', 11.34)]
# Topic 10: [('안하', 72.74), ('비추', 45.33), ('호우', 35.1), ('텍스트', 33.34), ('추천', 27.64)]
# Topic 11: [('경우', 35.74), ('미래', 31.72), ('일본', 28.15), ('설문', 22.92), ('게임', 21.37)]
# Topic 12: [('보스', 35.49), ('정상', 21.98), ('사진', 20.3), ('맞음', 19.83), ('여자', 19.07)]
# Topic 13: [('거지', 13.03), ('갤럭시', 6.95), ('무엇', 5.48), ('기능', 5.22), ('투자', 4.13)]
# Topic 14: [('오타', 141.82), ('오픈', 64.15), ('검열', 57.78), ('의지', 53.64), ('일부', 45.89)]
# Topic 15: [('장난', 18.52), ('기념', 18.03), ('인정', 15.13), ('구매', 12.88), ('검열', 11.85)]
# Topic 16: [('원석', 159.89), ('자신', 18.75), ('아래', 11.48), ('개창', 10.1), ('불안', 8.65)]
# Topic 17: [('재생', 89.25), ('한국어', 28.31), ('마찬가지', 22.34), ('검열', 9.25), ('호감', 7.94)]
# Topic 18: [('그동안', 23.44), ('미카', 9.57), ('지역', 9.5), ('버리', 6.49), ('제공', 6.23)]
# Topic 19: [('스타일', 25.66), ('평균', 7.85), ('흑우', 6.94), ('이오리', 6.69), ('검열', 4.49)]
# Topic 20: [('느림', 45.64), ('느낌', 33.31), ('필수', 30.5), ('천안문', 26.37), ('플레이어', 18.53)]
# Topic 21: [('컨텐츠', 108.25), ('시대', 69.0), ('검열', 31.88), ('형태', 26.4), ('혼자', 21.5)]
# Topic 22: [('우리', 41.58), ('하늘', 20.41), ('개임', 15.56), ('비상', 7.42), ('안정', 6.59)]
# Topic 23: [('시점', 31.85), ('무과', 25.68), ('다행', 9.6), ('날개', 5.62), ('원소', 2.71)]
# Topic 24: [('기가', 137.75), ('케릭', 31.78), ('취향', 29.55), ('그게', 28.65), ('며칠', 25.64)]
# Topic 25: [('사전', 25.93), ('조준', 10.35), ('희망', 5.03), ('안녕', 4.57), ('진입', 1.68)]
# Topic 26: [('리어', 122.42), ('로그인', 41.49), ('사이', 36.67), ('식량', 36.37), ('이유', 31.48)]
# Topic 27: [('음악', 11.85), ('정보', 8.23), ('히후', 6.44), ('동안', 5.88), ('초창기', 2.86)]
# Topic 28: [('출석', 29.73), ('이거', 25.83), ('사건', 22.29), ('나라', 13.12), ('힐링', 9.7)]
# Topic 29: [('아시아', 12.8), ('기준', 8.02), ('보이스', 7.2), ('마리', 6.17), ('마지막', 4.43)]
# Topic 30: [('검열', 619.79), ('공략', 112.03), ('컨셉', 96.45), ('선착순', 78.18), ('이것', 77.5)]
#
# ::: Topics - Okt :::
# Topic 1: [('그거', 48.48), ('일반', 24.39), ('붕괴', 22.5), ('이벤트', 15.94), ('개임', 15.24)]
# Topic 2: [('살짝', 105.44), ('방해', 77.34), ('검열', 57.53), ('레일', 54.23), ('시대', 39.83)]
# Topic 3: [('성의', 16.8), ('조정', 11.21), ('히후', 5.86), ('도움', 5.47), ('인식', 3.57)]
# Topic 4: [('여행', 11.62), ('무시', 11.5), ('직접', 9.15), ('페이', 3.59), ('길찾기', 3.48)]
# Topic 5: [('초창', 28.42), ('그냥', 27.11), ('리뷰', 25.4), ('멀티', 22.38), ('통해', 17.93)]
# Topic 6: [('스펙', 42.68), ('추천', 27.49), ('인생게임', 12.96), ('검열', 12.31), ('장점', 11.17)]
# Topic 7: [('재미나', 12.83), ('노력', 11.71), ('편의', 11.35), ('무슨', 7.59), ('상위', 6.52)]
# Topic 8: [('카메라', 82.97), ('클레', 34.52), ('페이스북', 19.23), ('검열', 18.98), ('스펙', 15.74)]
# Topic 9: [('시야', 30.89), ('영향', 25.44), ('음악회', 16.62), ('편이', 9.83), ('집중', 8.95)]
# Topic 10: [('루뾰이몰', 107.9), ('안해', 58.74), ('불편', 50.53), ('전용', 38.91), ('경우', 34.09)]
# Topic 11: [('방송', 127.18), ('사운드', 39.7), ('너희', 22.18), ('게임패드', 20.78), ('보이스', 20.56)]
# Topic 12: [('개발자', 236.77), ('원소', 155.05), ('오지', 79.21), ('유저', 46.71), ('검열', 40.72)]
# Topic 13: [('기적', 14.15), ('상황', 13.53), ('나머지', 10.14), ('다소', 5.9), ('기간', 5.17)]
# Topic 14: [('오픈월드', 61.72), ('아쉬움', 61.58), ('검열', 56.48), ('무한', 37.31), ('서버', 32.95)]
# Topic 15: [('비행', 142.56), ('화이팅', 142.27), ('그동안', 32.8), ('플스', 28.19), ('검열', 27.81)]
# Topic 16: [('금방', 75.2), ('난이', 36.71), ('어케', 13.82), ('전술', 12.53), ('필요', 12.53)]
# Topic 17: [('주작', 28.53), ('한국', 22.6), ('전투력', 18.48), ('노답', 8.62), ('만해', 5.71)]
# Topic 18: [('최고', 47.53), ('혼자', 40.33), ('에바', 22.08), ('어제', 22.01), ('하드', 18.79)]
# Topic 19: [('커녕', 24.05), ('출석', 18.53), ('하나요', 11.17), ('호불호', 10.96), ('우리', 9.39)]
# Topic 20: [('공지', 86.46), ('사냥', 79.58), ('검열', 71.26), ('개발자', 56.2), ('연속', 51.8)]
# Topic 21: [('고생', 13.9), ('만약', 11.5), ('아이', 11.39), ('재료', 9.64), ('이제', 8.76)]
# Topic 22: [('검열', 396.44), ('정작', 67.05), ('대부분', 35.3), ('아무', 33.39), ('실화', 25.3)]
# Topic 23: [('학생', 33.42), ('백도어', 14.09), ('양산', 8.77), ('걱정', 8.04), ('음악', 7.85)]
# Topic 24: [('보고', 32.27), ('일드', 22.59), ('공산당', 19.94), ('환불', 18.27), ('정리', 12.93)]
# Topic 25: [('지루함', 68.7), ('사람', 26.5), ('스파크', 17.46), ('김용하', 12.29), ('미션', 9.2)]
# Topic 26: [('기행', 35.63), ('국내', 31.4), ('목소리', 19.73), ('오역', 9.67), ('언제', 4.73)]
# Topic 27: [('검열', 78.72), ('점검', 67.03), ('새끼', 40.95), ('카메라', 38.34), ('픽뚫', 36.23)]
# Topic 28: [('루크', 90.0), ('누구', 50.81), ('최대', 30.22), ('컨텐츠', 23.1), ('피드백', 18.18)]
# Topic 29: [('천안문', 68.83), ('검열', 13.51), ('이하', 7.5), ('능력', 2.08), ('획득', 1.76)]
# Topic 30: [('친구', 83.61), ('장비', 77.23), ('일단', 39.16), ('비상식량', 37.8), ('스테이지', 21.36)]

# %%
print('::: Topics - Mecab :::')
n_k_LDA.get_topics(0, keyword_num = 5)
print()
print('::: Topics - Okt :::')
n_k_LDA.get_topics(1, keyword_num= 5)
print()
# Out:
# ::: Topics - Mecab :::
# Topic 1: [('콘솔', 101.52), ('성장', 27.7), ('검색', 19.77), ('테러', 11.19), ('네트워크', 10.54)]
# Topic 2: [('효율', 33.47), ('다행', 26.28), ('특성', 19.66), ('상담', 16.36), ('무지', 15.16)]
# Topic 3: [('불가', 61.37), ('캐시', 53.19), ('청불', 47.66), ('최소한', 37.93), ('우분', 34.43)]
# Topic 4: [('코코미', 46.55), ('무기', 29.53), ('신작', 26.72), ('퀘스트', 26.57), ('나오', 20.97)]
# Topic 5: [('우분', 260.18), ('마다', 46.76), ('다인', 35.07), ('계정', 32.26), ('돌파', 31.33)]
# Topic 6: [('전투', 178.66), ('오랫동안', 87.2), ('원소', 37.54), ('축하', 36.6), ('오픈', 22.87)]
# Topic 7: [('서브', 61.95), ('오랜만', 33.87), ('역대', 25.06), ('주인공', 13.31), ('눈물', 12.26)]
# Topic 8: [('다양', 83.51), ('하늘', 31.46), ('준비', 24.41), ('우분', 20.14), ('희망', 15.45)]
# Topic 9: [('게임패드', 481.8), ('다이아', 50.06), ('가격', 48.84), ('저격', 37.05), ('보석', 35.98)]
# Topic 10: [('최적', 86.85), ('생김', 68.97), ('아쉬움', 43.52), ('이정', 33.4), ('처음', 15.16)]
# Topic 11: [('취급', 73.88), ('칭찬', 56.61), ('그대', 49.9), ('버튼', 33.61), ('게임패드', 28.24)]
# Topic 12: [('갤럭시', 11.19), ('확정', 10.44), ('발전', 9.48), ('천안문', 8.35), ('요청', 7.65)]
# Topic 13: [('겁니까', 161.64), ('주변', 52.85), ('관심', 46.26), ('호요', 43.41), ('예상', 35.88)]
# Topic 14: [('와중', 55.05), ('화면', 49.2), ('분량', 24.46), ('본인', 19.27), ('상성', 14.51)]
# Topic 15: [('전환', 57.2), ('정지', 51.18), ('구매', 36.67), ('애플리케이션', 32.57), ('등록', 27.64)]
# Topic 16: [('기간', 203.43), ('자원', 42.72), ('폴드', 34.84), ('가차', 22.84), ('호구', 22.11)]
# Topic 17: [('카페', 36.13), ('컬쳐', 22.21), ('반대', 14.2), ('스파크', 13.78), ('할만', 12.46)]
# Topic 18: [('탄탄', 42.47), ('극악', 35.24), ('컨트롤', 26.18), ('요리', 19.34), ('조치', 15.63)]
# Topic 19: [('실력', 124.01), ('현질', 77.45), ('게임패드', 68.94), ('콘솔', 43.56), ('탈퇴', 39.48)]
# Topic 20: [('새끼', 28.46), ('요소', 26.65), ('경우', 23.65), ('의미', 22.77), ('무엇', 20.93)]
# Topic 21: [('마디', 118.25), ('동기', 75.08), ('어디', 63.94), ('아야카', 54.94), ('게임패드', 42.98)]
# Topic 22: [('마찬가지', 142.67), ('해결', 30.77), ('수집', 16.52), ('조절', 15.01), ('이름', 8.72)]
# Topic 23: [('공지', 279.35), ('설정', 99.06), ('게임패드', 59.62), ('이파', 57.14), ('하거', 43.46)]
# Topic 24: [('지장', 23.26), ('하루', 19.01), ('엠버', 12.92), ('이슈', 11.08), ('인민공화국', 10.7)]
# Topic 25: [('제작사', 50.02), ('사실', 28.74), ('해명', 23.32), ('인증', 21.8), ('우분', 19.7)]
# Topic 26: [('예정', 60.78), ('유료', 36.41), ('게임패드', 32.01), ('시점', 29.37), ('공지', 27.72)]
# Topic 27: [('그동안', 19.66), ('주년', 17.61), ('기획', 16.7), ('테스트', 11.43), ('행복', 10.06)]
# Topic 28: [('마지막', 78.0), ('이전', 52.58), ('시나리오', 49.21), ('홍련', 43.95), ('나라', 41.02)]
# Topic 29: [('음성', 111.61), ('이건', 64.39), ('게임패드', 60.5), ('개성', 56.26), ('매출', 46.51)]
# Topic 30: [('게임패드', 137.21), ('쓰레기', 73.1), ('우분', 70.45), ('공지', 66.8), ('개월', 45.88)]
#
# ::: Topics - Okt :::
# Topic 1: [('게임패드', 231.78), ('재화', 164.88), ('공식', 147.65), ('임무', 84.18), ('우리', 81.71)]
# Topic 2: [('던전', 72.31), ('게임패드', 54.16), ('닌텐', 48.64), ('테러', 44.47), ('실패', 44.36)]
# Topic 3: [('공식', 235.31), ('확정', 29.46), ('다이아', 27.18), ('복구', 26.04), ('개인정보', 17.37)]
# Topic 4: [('적용', 30.41), ('꿀잼', 28.79), ('바로', 22.47), ('장난', 22.44), ('고객', 14.88)]
# Topic 5: [('우리', 229.84), ('마침표', 47.95), ('스타일', 42.23), ('설계', 39.87), ('카메라', 35.64)]
# Topic 6: [('애니', 63.61), ('초기', 46.33), ('획득', 25.48), ('개임', 24.24), ('게임패드', 21.78)]
# Topic 7: [('김용', 65.23), ('완료', 36.9), ('표절', 34.55), ('혼자', 32.62), ('개선', 29.93)]
# Topic 8: [('육성', 86.74), ('장르', 34.29), ('의지', 32.7), ('게임패드', 23.7), ('한계', 17.14)]
# Topic 9: [('애니메이션', 21.44), ('파티', 12.03), ('효율', 9.18), ('클릭', 1.65), ('게임패드', 1.63)]
# Topic 10: [('사냥', 149.35), ('화질', 60.57), ('조치', 45.97), ('이유', 23.44), ('게임패드', 21.94)]
# Topic 11: [('옛날', 65.04), ('영상', 59.32), ('충전', 58.35), ('재밋네', 10.49), ('정도', 10.27)]
# Topic 12: [('사기', 42.42), ('하나요', 23.01), ('무엇', 19.4), ('찾기', 12.06), ('경험치', 10.32)]
# Topic 13: [('매우', 102.47), ('최고', 68.95), ('제한', 36.1), ('최신', 35.29), ('뭔가', 17.79)]
# Topic 14: [('상태', 60.98), ('우리', 52.1), ('형태', 51.23), ('심해', 36.47), ('운영자', 30.42)]
# Topic 15: [('리셋', 66.97), ('느낌', 48.73), ('관위', 46.5), ('막상', 21.21), ('환불', 15.71)]
# Topic 16: [('그래픽', 28.29), ('길찾기', 17.47), ('탈퇴', 8.92), ('화이팅', 8.91), ('어플', 7.12)]
# Topic 17: [('기능', 109.85), ('코드', 31.23), ('치명', 30.36), ('커뮤니티', 22.36), ('검수', 18.95)]
# Topic 18: [('네트워크', 57.52), ('개인', 48.9), ('취급', 47.03), ('오픈월드', 35.17), ('결과', 33.33)]
# Topic 19: [('시진핑', 141.24), ('컨트롤', 98.34), ('점수', 43.77), ('게임패드', 39.91), ('국내', 38.14)]
# Topic 20: [('게스트', 125.45), ('연차', 32.63), ('입장', 31.85), ('닌텐도', 24.58), ('상담', 24.45)]
# Topic 21: [('게임패드', 423.42), ('가격', 41.97), ('번역기', 31.79), ('덕분', 23.73), ('연동', 16.23)]
# Topic 22: [('호두', 30.33), ('사이', 27.45), ('어디', 22.46), ('무리', 19.15), ('저격', 16.93)]
# Topic 23: [('루크', 114.26), ('최적화', 67.58), ('민심', 23.62), ('고정', 15.43), ('게임패드', 15.13)]
# Topic 24: [('서비스', 80.14), ('차이', 71.21), ('정작', 56.08), ('퀘스트', 41.86), ('성격', 27.42)]
# Topic 25: [('상위', 72.91), ('잘만', 45.19), ('루뾰이몰', 42.82), ('정신', 42.29), ('우리', 34.94)]
# Topic 26: [('그때', 50.63), ('보지', 26.93), ('운영', 19.75), ('사료', 15.2), ('시대', 15.05)]
# Topic 27: [('화면', 39.84), ('특정', 24.06), ('중화인민공화국', 23.78), ('캐릭', 21.82), ('입력', 20.59)]
# Topic 28: [('리소스', 112.04), ('차지', 34.57), ('이후', 28.61), ('매출', 25.58), ('공식', 21.33)]
# Topic 29: [('안드로이드', 27.79), ('돌파', 24.94), ('정지', 18.2), ('생기', 15.12), ('잼남', 14.55)]
# Topic 30: [('그게', 69.29), ('컨텐츠', 44.62), ('동시', 18.37), ('센터', 17.48), ('수령', 15.51)]

# %%
print('::: Topics - Mecab :::')
o_g_LDA.get_topics(0, keyword_num = 5)
print()
print('::: Topics - Okt :::')
o_g_LDA.get_topics(1, keyword_num= 5)
print()
# Out:
# ::: Topics - Mecab :::
# Topic 1: [('원하', 229.7), ('조사', 205.81), ('혼자', 189.01), ('에피소드', 154.39), ('게이', 107.97)]
# Topic 2: [('스트레스', 189.12), ('사람', 43.5), ('상향', 33.72), ('시기', 24.02), ('축제', 13.19)]
# Topic 3: [('전환', 175.68), ('하드', 96.98), ('사운드', 84.71), ('시즌', 75.41), ('점수', 72.25)]
# Topic 4: [('최저', 427.8), ('만족', 115.41), ('게이', 75.05), ('호시노', 59.99), ('아래', 32.3)]
# Topic 5: [('게이', 1696.05), ('개판', 285.81), ('목소리', 128.8), ('부담', 82.38), ('힐링', 63.98)]
# Topic 6: [('건지', 102.19), ('코드', 92.04), ('케릭', 71.74), ('주인공', 68.51), ('단계', 54.98)]
# Topic 7: [('사실', 185.58), ('불편', 179.24), ('이전', 151.16), ('나부', 103.66), ('이름', 71.32)]
# Topic 8: [('설정', 317.95), ('우리', 274.48), ('공개', 159.06), ('전설', 155.7), ('부재', 136.2)]
# Topic 9: [('다인', 236.9), ('옵션', 178.17), ('뉴비', 162.86), ('유도', 146.46), ('게이', 80.4)]
# Topic 10: [('센터', 279.95), ('로비', 228.26), ('로그인', 175.02), ('감안', 111.49), ('배경', 103.49)]
# Topic 11: [('삭제', 236.26), ('현실', 146.1), ('해명', 104.04), ('순간', 90.92), ('진짜', 81.45)]
# Topic 12: [('리니지', 86.17), ('보상', 80.17), ('버전', 42.29), ('특성', 34.73), ('던전', 30.4)]
# Topic 13: [('시야', 332.16), ('작품', 228.53), ('게이', 216.93), ('장점', 168.49), ('니케', 151.83)]
# Topic 14: [('화면', 274.79), ('과금', 193.54), ('게이', 164.92), ('클레', 155.11), ('피드백', 148.61)]
# Topic 15: [('예약', 339.53), ('조절', 51.21), ('특징', 40.2), ('동시', 34.5), ('정책', 26.67)]
# Topic 16: [('정액', 526.94), ('개선', 189.64), ('플레이', 142.84), ('행동', 74.49), ('그건', 36.78)]
# Topic 17: [('일러스트', 139.32), ('게이', 53.08), ('리뷰', 40.99), ('기기', 25.09), ('스타', 8.52)]
# Topic 18: [('아기', 80.0), ('방해', 68.67), ('주년', 38.02), ('제작사', 27.75), ('사랑', 22.28)]
# Topic 19: [('전개', 661.29), ('극악', 633.85), ('출석', 283.95), ('장비', 207.09), ('불안', 176.46)]
# Topic 20: [('출시', 207.6), ('문장', 202.6), ('흑우', 143.47), ('스킵', 133.13), ('카드', 117.55)]
# Topic 21: [('식량', 223.25), ('게이', 173.29), ('사냥', 162.2), ('형식', 116.68), ('극악', 93.64)]
# Topic 22: [('시기', 243.69), ('키우', 207.99), ('하나', 185.73), ('토리', 158.56), ('오역', 157.98)]
# Topic 23: [('기본', 524.86), ('보석', 78.96), ('요리', 45.4), ('대가리', 39.59), ('국산', 29.12)]
# Topic 24: [('발생', 377.34), ('이게', 345.45), ('피로', 162.21), ('해결', 101.51), ('네트워크', 89.47)]
# Topic 25: [('다행', 173.14), ('참여', 161.1), ('중화', 155.49), ('리세', 104.03), ('기믹', 93.68)]
# Topic 26: [('배터리', 764.56), ('초보', 179.72), ('스타일', 105.71), ('게이', 84.12), ('랜덤', 82.77)]
# Topic 27: [('개월', 153.09), ('대응', 102.96), ('아무것', 102.47), ('마리안', 86.67), ('제외', 70.19)]
# Topic 28: [('치명', 171.17), ('고객', 147.22), ('정성', 146.01), ('연출', 140.01), ('콘솔', 123.31)]
# Topic 29: [('스킵', 503.32), ('지갑', 393.45), ('게이', 271.28), ('조준', 250.64), ('한국어', 98.57)]
# Topic 30: [('풀돌', 501.41), ('상황', 229.82), ('이미지', 229.04), ('게이', 180.5), ('재미', 142.49)]
#
# ::: Topics - Okt :::
# Topic 1: [('설치', 252.51), ('수메르', 183.9), ('비교', 105.02), ('거리', 86.95), ('시야', 82.25)]
# Topic 2: [('정지', 591.42), ('저격', 126.17), ('뽑기', 77.11), ('이따', 70.66), ('마침표', 66.23)]
# Topic 3: [('전투', 345.73), ('숙제', 288.69), ('게임패드', 150.44), ('콜라보', 135.02), ('커뮤니티', 125.48)]
# Topic 4: [('금방', 471.04), ('초보자', 386.5), ('추가', 169.84), ('게임패드', 156.0), ('인기', 153.49)]
# Topic 5: [('한마디', 82.38), ('장벽', 54.0), ('에바', 44.37), ('이동', 37.87), ('광고', 36.28)]
# Topic 6: [('뉴비', 146.18), ('플레이어', 138.16), ('누구', 122.65), ('최소한', 56.18), ('다만', 53.27)]
# Topic 7: [('사서', 253.99), ('제발', 209.15), ('해킹', 103.11), ('그게', 91.1), ('모션', 52.38)]
# Topic 8: [('속성', 508.87), ('최애', 401.18), ('와이파이', 260.8), ('게임패드', 174.22), ('음악', 107.1)]
# Topic 9: [('존재', 84.76), ('번역', 76.59), ('센터', 76.5), ('지갑', 73.26), ('투자', 70.51)]
# Topic 10: [('게임패드', 410.34), ('관리', 200.24), ('속성', 170.69), ('붕괴', 128.44), ('컨트롤', 109.16)]
# Topic 11: [('나름', 358.15), ('대박', 98.56), ('로딩', 78.42), ('연출', 74.16), ('시작', 32.07)]
# Topic 12: [('장난', 571.94), ('니케', 202.52), ('사항', 170.9), ('입장', 141.88), ('이메일', 64.57)]
# Topic 13: [('반복', 304.07), ('스위치', 277.45), ('로그인', 212.04), ('레이', 162.63), ('자꾸', 132.85)]
# Topic 14: [('개추', 455.85), ('게임패드', 273.0), ('종일', 198.72), ('기분', 193.72), ('퀘스트', 191.28)]
# Topic 15: [('오역', 146.68), ('공산당', 134.29), ('재밋다', 131.03), ('등급', 66.22), ('어이', 60.24)]
# Topic 16: [('일본', 192.37), ('여행자', 150.31), ('논란', 78.76), ('레벨', 68.17), ('페이', 66.93)]
# Topic 17: [('복사', 130.8), ('게임패드', 99.99), ('개인', 79.83), ('안함', 71.14), ('힐링', 70.6)]
# Topic 18: [('일본어', 178.26), ('탈퇴', 161.09), ('컨트롤러', 142.12), ('체감', 132.11), ('개성', 129.92)]
# Topic 19: [('여론', 326.71), ('확인', 175.54), ('신규', 102.17), ('게임패드', 67.89), ('커녕', 65.57)]
# Topic 20: [('무슨', 167.54), ('휴대폰', 133.7), ('장사', 109.64), ('나와라', 98.86), ('컷씬', 84.55)]
# Topic 21: [('게임패드', 1430.66), ('지장', 318.49), ('개발자', 162.23), ('입력', 129.06), ('에피소드', 93.51)]
# Topic 22: [('그래픽', 256.01), ('다이아', 166.93), ('찾기', 151.97), ('플스', 140.26), ('형태', 130.73)]
# Topic 23: [('보이', 40.76), ('그림', 38.73), ('차이', 35.37), ('알림', 34.82), ('용량', 33.26)]
# Topic 24: [('방식', 774.47), ('표현', 421.21), ('빡세', 171.84), ('아마', 160.04), ('게임패드', 125.99)]
# Topic 25: [('새끼', 306.02), ('붕괴', 305.66), ('제대', 182.47), ('가요', 60.23), ('아이템', 39.79)]
# Topic 26: [('고객', 250.84), ('정보', 129.09), ('투성이', 69.02), ('구글', 53.69), ('완료', 26.24)]
# Topic 27: [('장면', 115.32), ('다운로드', 110.79), ('감동', 97.86), ('충전', 94.83), ('젤다의전설', 86.53)]
# Topic 28: [('화질', 214.75), ('스타일', 189.97), ('고민', 144.02), ('여기', 121.44), ('안드로이드', 110.82)]
# Topic 29: [('주기', 329.93), ('전투력', 163.8), ('분위기', 150.44), ('프리코', 145.08), ('게임패드', 97.49)]
# Topic 30: [('다음', 245.24), ('코미', 68.88), ('모든', 51.81), ('픽업', 47.8), ('튕김', 44.09)]

# %%
print('::: Topics - Mecab :::')
d_s_LDA.get_topics(0, keyword_num = 5)
print()
print('::: Topics - Okt :::')
d_s_LDA.get_topics(1, keyword_num= 5)
print()
# Out:
# ::: Topics - Mecab :::
# Topic 1: [('복구', 118.4), ('개선', 51.62), ('식량', 30.46), ('설문', 15.78), ('하거', 12.93)]
# Topic 2: [('감사', 17.4), ('단점', 16.2), ('반천', 10.53), ('가능', 10.09), ('예약', 10.01)]
# Topic 3: [('개발', 31.37), ('필드', 19.5), ('미카', 19.21), ('한마디', 17.38), ('복구', 15.93)]
# Topic 4: [('해결', 2.14), ('중복', 1.38), ('성우진', 0.83), ('분량', 0.82), ('명작', 0.05)]
# Topic 5: [('치명', 27.93), ('서비스', 23.99), ('검수', 21.44), ('이걸', 20.73), ('마리안', 19.41)]
# Topic 6: [('실력', 27.74), ('나락', 13.16), ('엔드', 5.65), ('밸런스', 5.62), ('엉망', 4.9)]
# Topic 7: [('업적', 16.6), ('복구', 8.91), ('종려', 7.27), ('제미', 3.19), ('구매', 3.07)]
# Topic 8: [('오류', 31.21), ('실화', 12.9), ('예상', 6.89), ('성인', 6.4), ('인연', 2.87)]
# Topic 9: [('유지', 10.19), ('아래', 7.68), ('우분', 7.39), ('인증', 4.45), ('도박', 3.7)]
# Topic 10: [('지금', 6.65), ('챕터', 4.66), ('오역', 2.4), ('몰드', 1.43), ('정작', 1.32)]
# Topic 11: [('요청', 23.38), ('코코미', 19.73), ('업데이트', 18.24), ('취급', 13.7), ('소비', 11.67)]
# Topic 12: [('원석', 96.52), ('시일', 91.55), ('축하', 75.4), ('이동', 37.5), ('결국', 36.65)]
# Topic 13: [('호불호', 90.33), ('보임', 82.95), ('칭찬', 26.3), ('아이', 19.17), ('동기', 13.55)]
# Topic 14: [('결국', 54.43), ('정보', 50.57), ('클리어', 45.55), ('이야기', 36.83), ('플랫', 30.56)]
# Topic 15: [('청불', 5.15), ('풀돌', 4.43), ('시즌', 3.78), ('나무', 2.71), ('개발자', 1.61)]
# Topic 16: [('계정', 7.06), ('소리', 5.73), ('초창기', 1.06), ('선택', 0.09), ('에러', 0.04)]
# Topic 17: [('시스템', 36.6), ('호우', 26.57), ('마디', 18.46), ('수급', 16.24), ('필수', 14.87)]
# Topic 18: [('오브', 77.72), ('복구', 39.9), ('제작자', 29.13), ('결국', 25.65), ('시간', 21.13)]
# Topic 19: [('이건', 41.45), ('상자', 34.13), ('호두', 21.46), ('젤다', 14.89), ('컨트롤러', 14.87)]
# Topic 20: [('결국', 276.53), ('기억', 123.04), ('저번', 81.57), ('마다', 62.31), ('오류', 41.19)]
# Topic 21: [('기가', 42.04), ('리소스', 23.33), ('이게', 15.24), ('트위터', 12.68), ('부재', 10.77)]
# Topic 22: [('버스', 23.3), ('체감', 17.02), ('수준', 11.24), ('나머지', 8.1), ('초반', 2.61)]
# Topic 23: [('사진', 51.11), ('구동', 29.54), ('종료', 17.6), ('모션', 10.03), ('용량', 9.65)]
# Topic 24: [('결국', 103.93), ('케릭', 74.91), ('시점', 72.16), ('원석', 66.31), ('시작', 59.74)]
# Topic 25: [('지갑', 15.87), ('무소', 12.5), ('실시간', 11.23), ('학생', 7.51), ('메시지', 7.41)]
# Topic 26: [('날개', 4.1), ('수정', 3.19), ('임무', 0.09), ('갤럭시', 0.09), ('고객', 0.04)]
# Topic 27: [('성격', 2.32), ('오역', 0.15), ('용하', 0.07), ('라이트', 0.07), ('전작', 0.07)]
# Topic 28: [('시점', 48.29), ('관위', 32.99), ('결국', 22.46), ('인식', 21.96), ('답변', 19.64)]
# Topic 29: [('미션', 5.57), ('입력', 4.44), ('리셋', 2.96), ('이메일', 2.35), ('다인', 2.22)]
# Topic 30: [('만족', 16.12), ('평가', 6.18), ('옛날', 5.51), ('의외', 4.56), ('거기', 3.65)]
#
# ::: Topics - Okt :::
# Topic 1: [('원소', 20.65), ('인물', 13.8), ('여자', 12.64), ('역대', 5.15), ('하그', 4.12)]
# Topic 2: [('여기', 26.98), ('해명', 22.78), ('분량', 22.76), ('스토리', 21.58), ('애정', 20.39)]
# Topic 3: [('개발자', 51.83), ('축하', 30.08), ('결과', 16.78), ('수메르', 14.75), ('전용', 13.8)]
# Topic 4: [('마리', 50.01), ('정도', 39.28), ('옵션', 38.96), ('두번째', 20.94), ('콜라보', 16.56)]
# Topic 5: [('결과', 106.67), ('기만', 67.78), ('시장', 52.2), ('치명', 48.22), ('광고', 46.97)]
# Topic 6: [('구조', 29.15), ('정상', 29.07), ('조작', 17.33), ('옛날', 14.85), ('불편', 14.13)]
# Topic 7: [('렙업', 13.73), ('실행', 12.04), ('능력', 9.63), ('여행', 5.06), ('후반', 4.63)]
# Topic 8: [('보스', 26.99), ('안드로이드', 17.88), ('화면', 13.07), ('쓰레기', 10.27), ('컷신', 8.83)]
# Topic 9: [('개발', 26.56), ('그래픽', 11.46), ('전체', 5.54), ('이미지', 4.38), ('개돼지', 2.94)]
# Topic 10: [('대박', 19.09), ('충전', 18.27), ('난이', 12.81), ('거리', 10.38), ('재밋음', 9.86)]
# Topic 11: [('시로코', 83.09), ('재밋다', 70.19), ('전혀', 29.37), ('시장', 28.08), ('크기', 17.54)]
# Topic 12: [('난이도', 29.54), ('결과', 26.57), ('카페', 26.0), ('로딩', 22.27), ('분량', 19.26)]
# Topic 13: [('사진', 96.51), ('리얼', 59.54), ('시스템', 58.73), ('결과', 39.54), ('시대', 34.38)]
# Topic 14: [('라면', 33.99), ('최고', 17.83), ('만원', 17.29), ('장공', 12.63), ('메일', 12.42)]
# Topic 15: [('추천', 16.94), ('여러', 15.04), ('유료', 11.93), ('분량', 10.62), ('방법', 7.64)]
# Topic 16: [('소모', 15.28), ('일드', 14.92), ('대한', 11.5), ('준비', 11.45), ('이틀', 8.54)]
# Topic 17: [('옵션', 21.24), ('관련', 8.86), ('일러스트', 2.97), ('보지', 1.78), ('음악', 1.64)]
# Topic 18: [('홍련', 23.78), ('마음', 17.88), ('중간', 16.91), ('콘텐츠', 15.87), ('이제', 12.09)]
# Topic 19: [('상점', 33.18), ('혹시', 18.95), ('커녕', 15.48), ('호불호', 11.59), ('개성', 10.45)]
# Topic 20: [('길찾기', 82.72), ('부정', 79.32), ('연출', 46.61), ('기간', 35.58), ('다운', 29.2)]
# Topic 21: [('상담', 64.54), ('화질', 22.6), ('매력', 21.14), ('블루', 14.3), ('기회', 12.98)]
# Topic 22: [('고생', 35.12), ('문제', 14.93), ('발전', 13.59), ('결과', 12.64), ('서버', 12.15)]
# Topic 23: [('결과', 249.21), ('최소한', 58.42), ('이상', 12.31), ('보통', 10.82), ('의심', 10.38)]
# Topic 24: [('와우', 50.44), ('제외', 46.67), ('불만', 20.42), ('성우', 14.33), ('인연', 12.5)]
# Topic 25: [('분명', 10.26), ('권장', 9.22), ('커서', 8.82), ('장면', 8.45), ('만점', 5.64)]
# Topic 26: [('존재', 12.14), ('스토어', 9.79), ('성인', 5.83), ('그때', 3.15), ('테러', 2.52)]
# Topic 27: [('턴제', 84.92), ('무료', 7.17), ('필수', 7.11), ('반응', 5.88), ('어째서', 5.85)]
# Topic 28: [('분량', 129.46), ('집중', 61.41), ('크게', 33.77), ('결과', 28.58), ('컨텐츠', 27.4)]
# Topic 29: [('시장', 30.18), ('제대', 24.25), ('분량', 23.32), ('거기', 21.04), ('아무', 11.31)]
# Topic 30: [('최신', 16.36), ('젤다', 6.19), ('클리어', 3.8), ('청불', 3.05), ('루크', 3.01)]

# %%
ba = data[data['app_name'] == '블루아카이브']
b_a_pos = ba[ba['score'] > 3].reset_index()['content']
b_a_na = ba[ba['score'] < 3].reset_index()['content']

nk = data[data['app_name'] == '니케'].reset_index()
n_k_pos = nk[nk['score'] > 3].reset_index()['content']
n_k_na = nk[nk['score'] < 3].reset_index()['content']

og = data[data['app_name'] == '원신'].reset_index()
o_g_pos = og[og['score'] > 3].reset_index()['content']
o_g_na = og[og['score'] < 3].reset_index()['content']

ds = data[data['app_name'] == '붕괴:스타레일'].reset_index()
d_s_pos = ds[ds['score'] > 3].reset_index()['content']
d_s_na = ds[ds['score'] < 3].reset_index()['content']

# %%
ba_LDA_pos = custom_LDA(b_a_pos)
ba_LDA_na = custom_LDA(b_a_na)

nk_LDA_pos = custom_LDA(n_k_pos)
nk_LDA_na = custom_LDA(n_k_na)

og_LDA_pos = custom_LDA(o_g_pos)
og_LDA_na = custom_LDA(o_g_na)

ds_LDA_pos = custom_LDA(d_s_pos)
ds_LDA_na = custom_LDA(d_s_na)

# %%
print('::: Topics - Mecab :::')
ba_LDA_pos.get_topics(0, keyword_num = 5)
ba_LDA_na.get_topics(0, keyword_num=5)
print()
print('::: Topics - Okt :::')
ba_LDA_pos.get_topics(1, keyword_num= 5)
ba_LDA_na.get_topics(1, keyword_num=5)
print()
# Out:
# ::: Topics - Mecab :::
# Topic 1: [('무과', 7.72), ('현금', 6.38), ('스타일', 5.03), ('사용', 4.99), ('발전', 3.88)]
# Topic 2: [('시간', 36.97), ('방치', 7.08), ('기념', 5.9), ('음식', 3.98), ('기믹', 3.18)]
# Topic 3: [('버프', 16.44), ('본인', 5.12), ('파일', 4.37), ('통제', 2.07), ('체력', 2.06)]
# Topic 4: [('티켓', 32.99), ('컨셉', 16.83), ('이건', 11.41), ('나락', 8.68), ('삼성', 7.17)]
# Topic 5: [('오역', 31.74), ('겁니다', 16.6), ('형식', 13.86), ('이야기', 12.37), ('그대', 11.24)]
# Topic 6: [('무시', 7.36), ('가입', 6.59), ('쿠폰', 6.08), ('맞음', 5.81), ('패스', 4.26)]
# Topic 7: [('기기', 100.14), ('아야카', 70.62), ('부실', 44.93), ('불안', 43.11), ('겁니다', 31.24)]
# Topic 8: [('욕심', 18.81), ('실패', 10.53), ('이틀', 7.78), ('다인', 4.64), ('정지', 3.81)]
# Topic 9: [('불편', 38.61), ('부재', 21.22), ('거부', 6.54), ('희망', 5.57), ('대가리', 3.0)]
# Topic 10: [('키우', 22.17), ('호불호', 10.96), ('컴퓨터', 10.35), ('마찬가지', 10.06), ('주기', 10.0)]
# Topic 11: [('감사', 27.35), ('혼자', 22.5), ('시도', 21.31), ('최소', 16.64), ('호요', 13.8)]
# Topic 12: [('일부', 15.7), ('의견', 11.29), ('일반', 9.64), ('언제', 4.66), ('성유', 3.41)]
# Topic 13: [('오랫동안', 31.02), ('사기', 27.87), ('유출', 18.9), ('필수', 18.59), ('손절', 17.54)]
# Topic 14: [('과금', 43.27), ('로그아웃', 35.77), ('붕괴', 20.6), ('유튜브', 7.87), ('겁니다', 6.88)]
# Topic 15: [('엉망', 30.2), ('조심', 15.15), ('이벤트', 12.32), ('해결', 8.61), ('조금', 8.6)]
# Topic 16: [('겁니다', 434.1), ('취급', 84.15), ('이게', 40.88), ('강제', 20.6), ('카페', 14.61)]
# Topic 17: [('임무', 18.98), ('정신', 17.1), ('한국어', 11.91), ('카즈하', 10.48), ('이미지', 9.15)]
# Topic 18: [('기대', 12.63), ('버스', 5.22), ('직원', 3.76), ('보임', 3.6), ('예전', 3.12)]
# Topic 19: [('기준', 25.69), ('파밍', 6.95), ('이것', 6.78), ('공개', 4.69), ('짝퉁', 4.46)]
# Topic 20: [('이거', 31.26), ('옛날', 11.81), ('한국인', 6.63), ('차지', 5.83), ('건지', 5.53)]
# Topic 21: [('퀘스트', 142.08), ('겁니다', 106.14), ('스킨', 96.8), ('우분', 83.31), ('퀄리티', 58.58)]
# Topic 22: [('발견', 52.2), ('겁니다', 28.54), ('사랑', 17.33), ('컨트롤', 17.02), ('상자', 13.06)]
# Topic 23: [('옵션', 9.52), ('선녀', 9.17), ('레진', 2.59), ('한글', 2.48), ('제대', 1.48)]
# Topic 24: [('강화', 71.6), ('로그인', 39.04), ('비행', 23.17), ('하루', 16.52), ('분위기', 12.59)]
# Topic 25: [('적응', 49.99), ('홍보', 44.49), ('기획', 17.93), ('그동안', 16.87), ('플레', 13.99)]
# Topic 26: [('백도어', 24.92), ('히후', 7.27), ('피로', 6.58), ('부담', 4.48), ('자기', 4.27)]
# Topic 27: [('이전', 23.84), ('필그림', 21.6), ('두창', 9.66), ('무지', 8.37), ('오타쿠', 8.03)]
# Topic 28: [('상품', 10.14), ('콘솔', 4.68), ('유입', 4.15), ('상태', 3.23), ('지지', 3.21)]
# Topic 29: [('상성', 21.57), ('한국', 21.06), ('반대', 19.0), ('몰드', 17.3), ('마디', 16.17)]
# Topic 30: [('요청', 54.55), ('메시지', 24.27), ('개연', 15.29), ('몰루', 6.0), ('주세', 5.0)]
# Topic 1: [('평균', 7.75), ('주일', 2.12), ('주제', 2.02), ('마리', 1.58), ('경우', 1.15)]
# Topic 2: [('고퀄', 11.67), ('필그림', 5.44), ('지속', 3.31), ('세계관', 3.08), ('의문', 2.99)]
# Topic 3: [('응원', 15.12), ('바위', 10.63), ('감우', 9.44), ('제공', 8.51), ('반응', 7.06)]
# Topic 4: [('마라', 51.47), ('서사', 51.02), ('와이파이', 9.27), ('보이', 8.64), ('꼬라지', 5.4)]
# Topic 5: [('호감', 4.44), ('분량', 2.78), ('우분', 2.14), ('신청', 2.08), ('구동', 1.35)]
# Topic 6: [('삭제', 5.99), ('불만', 1.6), ('부분', 1.24), ('사진', 1.05), ('보안', 0.87)]
# Topic 7: [('확인', 97.31), ('방향', 88.51), ('겁니까', 63.19), ('마리', 57.49), ('캐릭터', 31.02)]
# Topic 8: [('유사', 40.77), ('하늘', 9.74), ('사태', 7.99), ('컨텐츠', 7.18), ('결국', 5.99)]
# Topic 9: [('실시간', 3.81), ('폴드', 1.34), ('자원', 1.2), ('초보', 0.47), ('별점', 0.37)]
# Topic 10: [('임무', 4.39), ('아쉬움', 4.13), ('응원', 4.05), ('뭔지', 3.89), ('기업', 3.83)]
# Topic 11: [('초반', 9.0), ('필수', 2.87), ('애니메이션', 2.32), ('오류', 1.84), ('인증', 1.32)]
# Topic 12: [('리소스', 21.14), ('성공', 5.14), ('소통', 4.83), ('나락', 4.37), ('대신', 3.96)]
# Topic 13: [('저장', 22.75), ('단계', 16.61), ('제한', 8.64), ('카즈하', 5.91), ('카페', 5.51)]
# Topic 14: [('겁니까', 126.64), ('유사', 21.84), ('최적화', 19.07), ('실화', 13.88), ('요청', 13.72)]
# Topic 15: [('호구', 4.87), ('결론', 4.65), ('사기', 4.09), ('따구', 3.23), ('사전', 2.99)]
# Topic 16: [('역사', 20.91), ('경쟁', 15.7), ('요청', 15.01), ('다행', 14.48), ('정도', 13.46)]
# Topic 17: [('요청', 36.27), ('버리', 20.94), ('스타', 16.42), ('겁니까', 11.77), ('정성', 7.84)]
# Topic 18: [('메인', 3.06), ('유료', 2.78), ('감동', 2.68), ('버스', 2.47), ('히후', 1.24)]
# Topic 19: [('안드로이드', 13.47), ('온라인', 7.04), ('중화', 5.26), ('풍경', 4.78), ('컬쳐', 4.49)]
# Topic 20: [('아래', 4.47), ('이전', 3.32), ('오타', 2.06), ('액션', 1.46), ('내요', 1.31)]
# Topic 21: [('강화', 111.67), ('방치', 25.22), ('겁니까', 14.68), ('상성', 11.74), ('필요', 7.28)]
# Topic 22: [('화면', 13.04), ('고려', 10.35), ('전반', 8.63), ('언어', 5.67), ('비행', 5.63)]
# Topic 23: [('이메일', 17.05), ('걱정', 8.69), ('사운드', 6.7), ('공식', 5.13), ('옵션', 3.07)]
# Topic 24: [('난이', 2.27), ('완벽', 1.97), ('존재', 1.94), ('공간', 1.1), ('스킨', 1.03)]
# Topic 25: [('추가', 14.4), ('시점', 4.9), ('불가', 4.17), ('화질', 3.6), ('관리', 2.32)]
# Topic 26: [('게이', 1.89), ('따름', 1.5), ('모르', 0.66), ('실행', 0.65), ('스테이지', 0.42)]
# Topic 27: [('추천', 8.74), ('개인', 4.68), ('방향', 2.29), ('발생', 1.76), ('난무', 1.15)]
# Topic 28: [('공지', 7.47), ('버프', 6.61), ('슈팅', 5.15), ('여러분', 4.37), ('개추', 3.23)]
# Topic 29: [('용량', 5.93), ('콘솔', 2.92), ('이것', 2.51), ('요즘', 2.39), ('전환', 1.56)]
# Topic 30: [('업데이트', 6.23), ('개연', 2.44), ('체험', 2.25), ('사양', 0.61), ('별점', 0.55)]
#
# ::: Topics - Okt :::
# Topic 1: [('재화', 13.29), ('재밋음', 9.26), ('설정', 7.38), ('블루아', 3.71), ('종일', 3.04)]
# Topic 2: [('접속', 55.13), ('시진핑', 28.72), ('게임패드', 23.21), ('최근', 16.01), ('비상식량', 9.92)]
# Topic 3: [('만해', 11.69), ('조정', 11.31), ('상점', 10.76), ('호감', 10.65), ('어이', 9.87)]
# Topic 4: [('의심', 8.22), ('전투', 4.3), ('신하', 4.04), ('매일', 3.43), ('노답', 2.34)]
# Topic 5: [('사전예약', 38.3), ('나름', 34.32), ('사기', 23.94), ('어쩌', 10.63), ('액션', 5.55)]
# Topic 6: [('창렬', 78.13), ('취급', 72.14), ('게임패드', 30.36), ('리얼', 29.8), ('상대', 18.73)]
# Topic 7: [('야생', 57.02), ('사과', 45.93), ('경험치', 16.85), ('전투력', 15.44), ('폴드', 11.77)]
# Topic 8: [('픽업', 17.87), ('애플리케이션', 17.87), ('어제', 8.69), ('직접', 6.43), ('구조', 6.38)]
# Topic 9: [('싸움', 17.27), ('하자', 9.83), ('인물', 7.86), ('필요', 7.22), ('보시', 6.82)]
# Topic 10: [('음악', 7.29), ('절대', 4.06), ('스위치', 3.12), ('완벽', 2.91), ('엉덩이', 2.59)]
# Topic 11: [('끼리', 23.48), ('찾기', 10.12), ('자꾸', 5.78), ('거임', 4.89), ('중국', 4.51)]
# Topic 12: [('일일', 17.99), ('이건', 10.52), ('안해', 10.05), ('기행', 3.94), ('흥미', 3.81)]
# Topic 13: [('안주', 34.88), ('와우', 10.87), ('완전', 9.94), ('컷씬', 9.46), ('시스템', 9.36)]
# Topic 14: [('사용', 98.73), ('게임패드', 96.66), ('관심', 77.44), ('취급', 69.03), ('화면', 58.63)]
# Topic 15: [('초보자', 22.86), ('하라', 15.1), ('주변', 14.19), ('이만', 13.96), ('시도', 13.46)]
# Topic 16: [('실화', 35.56), ('마리안', 23.83), ('몇몇', 23.18), ('질리', 14.65), ('의지', 14.63)]
# Topic 17: [('동영상', 9.02), ('로써', 4.91), ('현질', 3.08), ('모든', 2.02), ('몇개', 1.78)]
# Topic 18: [('혼자', 25.15), ('에피소드', 15.72), ('류웨', 11.98), ('뽑기', 8.18), ('웨이', 6.75)]
# Topic 19: [('그게', 26.29), ('인생', 8.63), ('이상', 2.82), ('회사', 2.01), ('다음', 1.57)]
# Topic 20: [('중화인민공화국', 39.5), ('덩어리', 26.76), ('그때', 19.78), ('글로벌', 15.98), ('게임패드', 13.53)]
# Topic 21: [('게임패드', 425.28), ('개발자', 77.43), ('웨이', 61.42), ('번역기', 52.29), ('클리어', 34.27)]
# Topic 22: [('무리', 18.66), ('보이지', 3.2), ('픽뚫', 2.23), ('관리', 1.17), ('두창', 0.04)]
# Topic 23: [('날개', 8.06), ('사양', 5.12), ('획득', 4.84), ('최신', 4.7), ('느낌', 4.04)]
# Topic 24: [('정작', 55.14), ('여러분', 24.15), ('체감', 20.63), ('웨이', 15.84), ('복귀', 15.29)]
# Topic 25: [('완료', 27.69), ('옵션', 24.88), ('혹시', 22.05), ('다른', 17.93), ('나선', 17.69)]
# Topic 26: [('기분', 61.01), ('한게임', 10.12), ('행동', 7.52), ('에러', 2.73), ('국산', 2.03)]
# Topic 27: [('재밋네', 11.63), ('영향', 11.47), ('당신', 4.96), ('스킬', 3.4), ('연동', 3.32)]
# Topic 28: [('부분', 16.27), ('재밋어', 11.48), ('오픈월드', 10.39), ('한가지', 4.9), ('원소', 3.62)]
# Topic 29: [('하복', 19.84), ('울트라', 18.21), ('이전', 15.62), ('일주일', 13.95), ('리뷰', 12.19)]
# Topic 30: [('재밋', 36.03), ('소리', 9.82), ('학생', 5.49), ('은근', 4.2), ('매출', 2.42)]
# Topic 1: [('재화', 1.32), ('매우', 0.38), ('종일', 0.25), ('어제', 0.25), ('부족', 0.22)]
# Topic 2: [('애정', 16.03), ('애플리케이션', 14.4), ('등급', 6.36), ('게임패드', 6.3), ('플레', 5.83)]
# Topic 3: [('이기', 16.89), ('개꿀', 9.31), ('지역', 6.98), ('출석', 6.41), ('소리', 6.04)]
# Topic 4: [('차이', 7.47), ('난이도', 2.39), ('원래', 1.97), ('필수', 1.79), ('마다', 1.78)]
# Topic 5: [('울트라', 46.23), ('다음', 22.06), ('재밋어', 20.17), ('마음', 20.1), ('보스', 19.54)]
# Topic 6: [('수동', 6.74), ('최악', 5.58), ('설정', 5.53), ('은근', 4.76), ('동영상', 3.37)]
# Topic 7: [('정리', 5.56), ('한계', 2.61), ('다행', 1.46), ('포함', 1.21), ('남캐', 0.88)]
# Topic 8: [('백도어', 5.26), ('제작자', 2.91), ('속도', 2.73), ('감사', 2.71), ('하니', 1.46)]
# Topic 9: [('개발', 105.49), ('요구', 23.58), ('다운로드', 13.78), ('게임패드', 11.7), ('설명', 4.01)]
# Topic 10: [('주작', 3.77), ('미코', 3.71), ('튕기', 3.24), ('이메일', 2.3), ('신인', 2.25)]
# Topic 11: [('성격', 51.96), ('막상', 46.13), ('만드', 20.07), ('자유도', 16.08), ('환경', 9.5)]
# Topic 12: [('상담', 12.22), ('욕심', 10.7), ('결론', 8.65), ('투성이', 8.24), ('오류', 7.35)]
# Topic 13: [('크기', 4.39), ('천장', 1.36), ('전투력', 0.9), ('방식', 0.47), ('씹덕', 0.4)]
# Topic 14: [('체감', 13.38), ('발견', 8.43), ('해결', 6.03), ('마리안', 6.0), ('여러', 5.58)]
# Topic 15: [('방랑자', 9.25), ('수메르', 7.11), ('정신', 6.9), ('발열', 5.5), ('패키지', 5.44)]
# Topic 16: [('노력', 21.19), ('된거', 2.81), ('게임패드', 2.05), ('상담', 0.41), ('확률', 0.39)]
# Topic 17: [('스타일', 12.42), ('요즘', 3.49), ('하그', 0.27), ('확률', 0.26), ('다소', 0.24)]
# Topic 18: [('오픈', 3.25), ('이유', 3.15), ('음식', 2.36), ('전략', 1.52), ('항전', 1.0)]
# Topic 19: [('주시', 14.65), ('포인트', 7.89), ('엉덩이', 5.28), ('평생', 3.51), ('현상', 3.11)]
# Topic 20: [('개임', 3.16), ('기대', 2.47), ('파티', 2.27), ('필드', 2.18), ('적대', 0.94)]
# Topic 21: [('게임패드', 164.58), ('확률', 88.4), ('상담', 55.47), ('개발', 37.62), ('울트라', 35.31)]
# Topic 22: [('제발', 11.69), ('직접', 9.87), ('공략', 8.75), ('사진', 8.44), ('계정', 8.34)]
# Topic 23: [('모델', 1.78), ('정지', 1.27), ('불편', 0.52), ('승리', 0.35), ('재생', 0.21)]
# Topic 24: [('퀘스트', 6.26), ('장면', 4.5), ('도안', 2.93), ('하복', 2.9), ('게스트', 2.4)]
# Topic 25: [('초기', 15.34), ('옛날', 14.87), ('계속', 8.93), ('복사', 7.0), ('화이팅', 6.64)]
# Topic 26: [('진짜', 2.39), ('차지', 0.83), ('복귀', 0.67), ('여태', 0.35), ('더빙', 0.25)]
# Topic 27: [('응애', 46.9), ('생기', 7.31), ('최고다', 4.76), ('경쟁', 4.43), ('게임패드', 4.34)]
# Topic 28: [('장난', 6.62), ('상향', 5.4), ('부분', 5.25), ('세상', 4.78), ('회원', 4.76)]
# Topic 29: [('관위', 11.87), ('메인', 4.64), ('웨이', 3.87), ('장벽', 3.61), ('게임패드', 3.58)]
# Topic 30: [('보고', 75.52), ('알람', 22.44), ('장사', 9.0), ('세계관', 5.19), ('대응', 4.68)]

# %%
print('::: Topics - Mecab :::')
og_LDA_pos.get_topics(0, keyword_num = 5)
og_LDA_na.get_topics(0, keyword_num=5)
print()
print('::: Topics - Okt :::')
og_LDA_pos.get_topics(1, keyword_num= 5)
og_LDA_na.get_topics(1, keyword_num=5)
print()
# Out:
# ::: Topics - Mecab :::
# Topic 1: [('요구', 112.08), ('말씀', 83.37), ('쿠폰', 68.68), ('리뷰', 54.96), ('게임패드', 54.8)]
# Topic 2: [('탄압', 166.9), ('개인', 112.81), ('로비', 54.48), ('정지', 49.97), ('숙제', 44.88)]
# Topic 3: [('충전', 150.69), ('언어', 62.87), ('카프카', 43.22), ('작동', 27.96), ('동일', 24.06)]
# Topic 4: [('최애', 415.17), ('게임패드', 96.02), ('니다', 74.9), ('불가', 50.52), ('흥미', 38.77)]
# Topic 5: [('글로벌', 459.61), ('예상', 138.48), ('시간', 123.35), ('우분', 105.1), ('게임패드', 99.99)]
# Topic 6: [('풀돌', 205.62), ('게임패드', 166.37), ('인증', 144.19), ('다운로드', 111.99), ('최소한', 97.57)]
# Topic 7: [('방법', 212.89), ('추후', 162.4), ('게임패드', 145.19), ('문장', 124.67), ('스킬', 123.15)]
# Topic 8: [('해당', 70.43), ('미안', 45.44), ('집중', 39.26), ('페이', 33.93), ('걸리', 28.13)]
# Topic 9: [('시스템', 196.26), ('개월', 196.07), ('작용', 152.45), ('엉망', 70.72), ('형식', 65.01)]
# Topic 10: [('위치', 175.02), ('마지막', 53.92), ('스킵', 49.5), ('게임패드', 36.07), ('무기', 33.97)]
# Topic 11: [('스킬', 368.52), ('종류', 129.58), ('오타', 71.36), ('연차', 71.03), ('사양', 46.63)]
# Topic 12: [('목소리', 119.81), ('레벨', 62.07), ('뉴비', 31.62), ('중요', 29.61), ('몰루', 28.06)]
# Topic 13: [('평가', 63.79), ('장점', 54.61), ('없음', 40.34), ('완전', 40.26), ('신규', 27.68)]
# Topic 14: [('기분', 424.19), ('지급', 115.73), ('게임패드', 111.34), ('나중', 101.55), ('친절', 93.37)]
# Topic 15: [('블루', 134.12), ('제대', 43.04), ('온라인', 37.21), ('유저', 26.38), ('길드', 21.55)]
# Topic 16: [('대체', 100.45), ('단점', 67.37), ('공략', 37.18), ('리소스', 30.43), ('한계', 21.56)]
# Topic 17: [('커뮤니티', 40.65), ('이정', 19.2), ('평점', 16.89), ('미래', 15.99), ('사람', 15.39)]
# Topic 18: [('전반', 556.66), ('주년', 19.74), ('당장', 13.57), ('단계', 12.41), ('진입', 12.23)]
# Topic 19: [('블레이드', 119.71), ('정도', 110.61), ('게임패드', 76.48), ('피곤', 66.02), ('해명', 64.75)]
# Topic 20: [('시간', 215.1), ('화면', 148.99), ('타격', 137.44), ('케릭', 98.97), ('시장', 66.13)]
# Topic 21: [('단어', 90.74), ('컴퓨터', 62.09), ('코코미', 57.99), ('모션', 35.07), ('방송', 22.8)]
# Topic 22: [('이전', 77.85), ('리세', 48.52), ('사냥', 41.72), ('보안', 36.4), ('여자', 20.84)]
# Topic 23: [('사실', 112.4), ('이게', 70.79), ('메일', 44.84), ('구글', 33.75), ('게임패드', 28.48)]
# Topic 24: [('이메일', 115.68), ('원활', 52.61), ('종려', 51.14), ('검열', 24.39), ('게임패드', 23.81)]
# Topic 25: [('설명', 53.85), ('거부', 42.88), ('사항', 27.79), ('때문', 26.48), ('포함', 22.92)]
# Topic 26: [('중국', 27.0), ('반대', 23.69), ('미소녀', 15.11), ('로그아웃', 13.33), ('공간', 7.47)]
# Topic 27: [('게임패드', 201.38), ('상황', 170.55), ('옵션', 161.52), ('관리', 143.71), ('유사', 130.75)]
# Topic 28: [('이것', 170.07), ('초보', 113.22), ('게임패드', 39.39), ('지역', 30.01), ('성우', 14.48)]
# Topic 29: [('게임패드', 1459.12), ('감안', 81.32), ('이동', 35.79), ('그거', 34.68), ('스파크', 27.79)]
# Topic 30: [('장비', 197.71), ('하나', 108.33), ('조정', 102.69), ('스토어', 75.82), ('탄탄', 57.65)]
# Topic 1: [('겁니까', 312.41), ('카즈하', 21.88), ('고치', 20.35), ('리셋', 19.53), ('사랑', 16.61)]
# Topic 2: [('반응', 143.1), ('스킨', 142.56), ('이거', 133.89), ('겁니까', 75.3), ('시장', 65.58)]
# Topic 3: [('실시간', 41.78), ('여론', 25.55), ('대사', 16.84), ('시즌', 14.18), ('나락', 14.08)]
# Topic 4: [('장면', 50.51), ('스킵', 39.0), ('기만', 31.21), ('인간', 21.48), ('불가', 13.41)]
# Topic 5: [('세계관', 94.63), ('사진', 66.51), ('현상', 57.85), ('흥미', 47.06), ('제미', 39.53)]
# Topic 6: [('중국', 134.11), ('별점', 78.6), ('어려움', 22.27), ('예전', 15.21), ('상관', 15.04)]
# Topic 7: [('지장', 206.8), ('요청', 126.64), ('친절', 74.77), ('겁니까', 72.68), ('불편', 34.04)]
# Topic 8: [('특징', 10.85), ('도전', 7.55), ('종류', 7.47), ('상향', 6.29), ('센터', 5.53)]
# Topic 9: [('이젠', 26.82), ('동시', 14.03), ('온라인', 12.43), ('참고', 12.33), ('매력', 8.26)]
# Topic 10: [('전체', 120.36), ('고유', 112.59), ('부실', 78.53), ('애초', 65.24), ('레벨', 31.44)]
# Topic 11: [('상성', 173.36), ('커뮤니티', 34.78), ('양심', 24.7), ('서버', 19.37), ('인기', 18.66)]
# Topic 12: [('리세', 93.76), ('경쟁', 67.88), ('리소스', 24.52), ('추가', 23.63), ('실제', 21.57)]
# Topic 13: [('답변', 116.41), ('엉망', 79.1), ('치치', 50.61), ('시로코', 49.11), ('최신', 29.09)]
# Topic 14: [('영향', 111.48), ('환경', 81.42), ('스테이지', 63.7), ('겁니까', 62.71), ('공략', 51.28)]
# Topic 15: [('청불', 73.35), ('주기', 64.93), ('그동안', 58.82), ('겁니까', 55.65), ('사실', 50.03)]
# Topic 16: [('존재', 82.7), ('초반', 74.9), ('접속', 66.71), ('용하', 44.45), ('겁니까', 41.49)]
# Topic 17: [('방향', 425.18), ('설치', 108.27), ('이나즈마', 88.22), ('필그림', 79.9), ('느림', 60.67)]
# Topic 18: [('제외', 264.35), ('개인', 229.08), ('유입', 50.97), ('겁니까', 38.0), ('재미', 34.05)]
# Topic 19: [('패스', 19.0), ('그건', 16.96), ('릭터', 12.94), ('문제', 12.21), ('최고', 9.37)]
# Topic 20: [('호구', 36.48), ('행복', 31.65), ('대비', 22.97), ('설명', 21.21), ('사용', 20.31)]
# Topic 21: [('투자', 93.93), ('리니지', 88.1), ('겁니까', 86.17), ('확률', 79.15), ('스킨', 74.95)]
# Topic 22: [('능력', 52.05), ('사전', 42.25), ('로딩', 40.07), ('무시', 33.67), ('선녀', 31.7)]
# Topic 23: [('개돼지', 33.84), ('희망', 13.42), ('코드', 11.09), ('보상', 7.41), ('기본', 5.87)]
# Topic 24: [('제대', 80.16), ('역사', 41.67), ('지원', 35.83), ('관심', 30.91), ('경쟁', 17.91)]
# Topic 25: [('당신', 76.56), ('리어', 65.76), ('오브', 64.52), ('하거', 22.73), ('활용', 20.64)]
# Topic 26: [('시진핑', 35.04), ('한글', 30.07), ('방랑자', 12.37), ('오역', 10.25), ('계정', 9.33)]
# Topic 27: [('실행', 71.01), ('건가요', 52.92), ('콜라보', 19.2), ('해결', 18.08), ('겁니까', 18.08)]
# Topic 28: [('인식', 37.38), ('이외', 34.65), ('조아', 28.46), ('겁니까', 24.0), ('반천', 23.24)]
# Topic 29: [('초기', 42.27), ('번호', 41.08), ('이것', 27.39), ('효율', 23.95), ('쿠폰', 21.19)]
# Topic 30: [('피곤', 232.87), ('전반', 64.93), ('겁니까', 45.09), ('손해', 13.58), ('대부분', 7.59)]
#
# ::: Topics - Okt :::
# Topic 1: [('폰신', 187.92), ('정지', 138.33), ('번역', 70.99), ('응원', 62.58), ('와이파이', 58.56)]
# Topic 2: [('최소한', 132.8), ('개성', 109.26), ('전작', 47.61), ('역시', 40.31), ('출석', 36.99)]
# Topic 3: [('김용하', 363.89), ('일부', 123.89), ('재료', 85.99), ('속성', 39.92), ('장비', 34.16)]
# Topic 4: [('청불', 378.35), ('숨결', 329.63), ('검열', 185.56), ('만하', 76.14), ('이제', 61.98)]
# Topic 5: [('처리', 81.21), ('충전', 39.02), ('무엇', 19.22), ('개판', 18.9), ('재밋어', 18.66)]
# Topic 6: [('제대', 109.99), ('커녕', 96.07), ('이틀', 91.33), ('플레이어', 45.24), ('화이팅', 35.86)]
# Topic 7: [('전투력', 315.65), ('정액', 302.83), ('화질', 129.79), ('검열', 102.48), ('정리', 88.06)]
# Topic 8: [('쿠폰', 167.14), ('나라', 89.53), ('설명', 50.23), ('화면', 32.9), ('장사', 28.48)]
# Topic 9: [('종려', 87.46), ('어플', 74.24), ('그게', 44.47), ('일일', 34.88), ('공간', 33.99)]
# Topic 10: [('완벽', 98.96), ('사람', 79.17), ('대한', 50.27), ('대충', 31.09), ('모두', 30.46)]
# Topic 11: [('국산', 35.02), ('조치', 24.78), ('한가지', 19.34), ('반응', 18.53), ('용량', 10.12)]
# Topic 12: [('장난', 470.94), ('닌텐도', 142.89), ('그닥', 131.56), ('미션', 93.0), ('현재', 79.14)]
# Topic 13: [('홍련', 63.32), ('필수', 41.61), ('바로', 39.56), ('혹시', 28.43), ('양산', 24.16)]
# Topic 14: [('검열', 293.96), ('여신', 135.31), ('경험', 131.55), ('숨결', 120.47), ('장면', 108.33)]
# Topic 15: [('검열', 173.5), ('콘솔', 131.65), ('과금', 129.06), ('예정', 96.38), ('다인', 91.91)]
# Topic 16: [('쓰레기', 35.75), ('구간', 33.66), ('모델링', 32.22), ('티켓', 26.99), ('원래', 25.87)]
# Topic 17: [('방해', 142.18), ('오토', 107.88), ('야생', 52.47), ('불가능', 42.26), ('오지', 40.55)]
# Topic 18: [('자꾸', 119.64), ('재밋', 81.49), ('로그아웃', 57.34), ('루뾰이몰', 53.53), ('수메르', 50.79)]
# Topic 19: [('인생', 110.01), ('시로코', 64.33), ('검열', 62.39), ('가끔', 61.13), ('제한', 46.96)]
# Topic 20: [('여러가지', 67.51), ('예전', 66.71), ('루크', 45.69), ('경험치', 41.65), ('새끼', 36.69)]
# Topic 21: [('그래픽', 407.87), ('스택', 282.93), ('비예', 135.0), ('카페', 127.64), ('굿굿', 90.9)]
# Topic 22: [('일차', 136.41), ('스킬', 75.29), ('일본어', 74.91), ('기대', 63.54), ('마냥', 49.4)]
# Topic 23: [('안나', 149.32), ('장점', 110.87), ('전반', 17.4), ('김용', 13.59), ('버벅', 11.06)]
# Topic 24: [('스펙', 190.66), ('느낌', 63.61), ('어쩌', 29.54), ('사태', 27.69), ('체감', 23.98)]
# Topic 25: [('상품', 140.33), ('대신', 95.35), ('차지', 88.18), ('프로그램', 81.51), ('검열', 78.74)]
# Topic 26: [('거리', 40.04), ('먼저', 38.8), ('투성이', 28.08), ('옛날', 18.64), ('주기', 17.19)]
# Topic 27: [('검열', 1210.23), ('지속', 298.87), ('개선', 171.94), ('종료', 77.42), ('젤다', 47.86)]
# Topic 28: [('최고다', 203.61), ('사실', 115.16), ('갈수록', 91.67), ('주시', 76.3), ('패드', 61.14)]
# Topic 29: [('제작자', 89.6), ('장벽', 54.09), ('이후', 39.26), ('권장', 32.48), ('후회', 12.59)]
# Topic 30: [('기도', 182.93), ('사과', 147.93), ('프리코', 99.22), ('최적화', 82.35), ('검열', 76.51)]
# Topic 1: [('튜토리얼', 30.91), ('클릭', 24.97), ('만드', 15.03), ('히후', 13.53), ('매우', 10.6)]
# Topic 2: [('스킨', 204.18), ('겨우', 119.95), ('배경', 119.14), ('스펙', 119.06), ('대가리', 94.97)]
# Topic 3: [('별로', 425.87), ('마지막', 90.99), ('실화', 48.89), ('웨이', 44.82), ('겨우', 41.92)]
# Topic 4: [('고객', 78.83), ('캐릭터', 39.61), ('무조건', 19.54), ('심해', 19.28), ('데차', 19.08)]
# Topic 5: [('사랑', 118.15), ('소비자', 105.31), ('환불', 68.33), ('금방', 49.64), ('겨우', 39.23)]
# Topic 6: [('존재', 135.86), ('복각', 76.72), ('어쩌', 18.18), ('상대', 14.07), ('무지', 12.11)]
# Topic 7: [('탐험', 93.77), ('선택', 35.34), ('후반', 31.48), ('이제', 29.21), ('제외', 23.52)]
# Topic 8: [('피로', 40.9), ('국내', 28.56), ('보시', 13.88), ('자동', 11.65), ('문제', 11.5)]
# Topic 9: [('실제', 45.27), ('장르', 26.57), ('가차', 24.84), ('효율', 23.32), ('단점', 22.82)]
# Topic 10: [('저격', 102.3), ('공지', 96.35), ('약간', 61.03), ('전작', 31.51), ('로그', 29.38)]
# Topic 11: [('호감', 38.57), ('다이아', 35.1), ('정성', 30.17), ('출시', 27.04), ('튕김', 27.01)]
# Topic 12: [('스트레스', 15.98), ('빵댕', 15.66), ('통제', 10.78), ('참고', 8.67), ('날개', 8.43)]
# Topic 13: [('계정', 62.7), ('절대', 45.88), ('구성', 40.24), ('한참', 38.17), ('확정', 35.38)]
# Topic 14: [('원소', 132.11), ('최악', 86.66), ('진행중', 65.67), ('제발', 34.48), ('자주', 34.17)]
# Topic 15: [('당장', 57.8), ('싸움', 52.95), ('최소한', 52.01), ('자꾸', 40.67), ('겨우', 29.37)]
# Topic 16: [('성장', 111.84), ('점점', 85.71), ('플레이어', 79.47), ('자기', 59.57), ('다만', 56.33)]
# Topic 17: [('개인', 253.0), ('주변', 199.86), ('겨우', 87.87), ('응애', 34.46), ('순위', 32.32)]
# Topic 18: [('호시노', 33.68), ('개꿀잼', 32.11), ('당신', 27.08), ('전체', 26.27), ('역대', 25.55)]
# Topic 19: [('전환', 68.97), ('된거', 21.24), ('그동안', 15.52), ('드랍', 15.2), ('먼저', 14.94)]
# Topic 20: [('마냥', 60.9), ('지지', 59.27), ('직접', 56.8), ('이동', 48.01), ('사운드', 46.32)]
# Topic 21: [('그래픽', 82.32), ('현상', 56.31), ('제작', 46.82), ('정액', 42.88), ('장면', 32.82)]
# Topic 22: [('제대로', 235.25), ('사항', 50.85), ('주년', 44.09), ('전개', 41.38), ('영향', 36.96)]
# Topic 23: [('애니메이션', 20.07), ('마찬가지', 18.44), ('컷신', 16.53), ('무소', 11.01), ('느낌', 5.38)]
# Topic 24: [('겨우', 249.08), ('프리코', 206.97), ('이유', 30.48), ('최적화', 24.23), ('과정', 21.16)]
# Topic 25: [('여러분', 74.53), ('스킬', 35.09), ('하루', 17.13), ('이해', 16.66), ('에피소드', 14.66)]
# Topic 26: [('씹덕', 71.79), ('겨우', 65.3), ('스택', 41.31), ('커녕', 33.56), ('하라', 32.58)]
# Topic 27: [('재밋네', 61.04), ('뽑기', 27.65), ('사전', 21.15), ('재미', 13.1), ('서버', 10.76)]
# Topic 28: [('상태', 143.85), ('오픈월드', 71.95), ('한가지', 44.53), ('시로코', 43.43), ('살짝', 35.8)]
# Topic 29: [('다소', 50.16), ('시장', 28.54), ('콘솔', 26.55), ('부족', 25.17), ('요소', 19.7)]
# Topic 30: [('오류', 100.4), ('다른', 69.08), ('스타일', 60.71), ('와이파이', 26.14), ('체감', 23.28)]

# %%
print('::: Topics - Mecab :::')
ds_LDA_pos.get_topics(0, keyword_num = 5)
ds_LDA_na.get_topics(0, keyword_num=5)
print()
print('::: Topics - Okt :::')
ds_LDA_pos.get_topics(1, keyword_num= 5)
ds_LDA_na.get_topics(1, keyword_num=5)
print()
# Out:
# ::: Topics - Mecab :::
# Topic 1: [('기존', 3.81), ('이오리', 0.36), ('블루아', 0.18), ('한국', 0.17), ('유료', 0.17)]
# Topic 2: [('개성', 25.46), ('답변', 5.08), ('컨트롤러', 3.84), ('선택', 3.75), ('일정', 2.49)]
# Topic 3: [('버프', 22.38), ('풀돌', 8.4), ('스테이지', 5.56), ('울트라', 5.16), ('경우', 4.93)]
# Topic 4: [('이게', 3.8), ('시로코', 1.94), ('모델', 0.08), ('명작', 0.08), ('신작', 0.08)]
# Topic 5: [('기회', 100.34), ('참고', 1.28), ('특성', 1.04), ('거부', 0.67), ('보이', 0.63)]
# Topic 6: [('사태', 4.77), ('종류', 2.65), ('필요', 2.27), ('흑우', 2.14), ('최대', 1.87)]
# Topic 7: [('이거', 4.01), ('고치', 3.44), ('역대', 3.22), ('치명', 2.4), ('전환', 2.33)]
# Topic 8: [('뉴비', 4.26), ('라이트', 3.63), ('부탁', 3.45), ('센터', 2.23), ('경험', 1.64)]
# Topic 9: [('패드', 2.49), ('클릭', 2.37), ('낭비', 2.14), ('할만', 1.99), ('엉망', 1.31)]
# Topic 10: [('블루아', 35.48), ('스타일', 33.15), ('레전드', 32.94), ('유료', 15.82), ('경험', 9.48)]
# Topic 11: [('카드', 35.05), ('사랑', 22.88), ('컨셉', 10.81), ('리어', 5.07), ('시점', 4.62)]
# Topic 12: [('적대', 32.22), ('모델', 5.13), ('경험', 3.51), ('오랜만', 3.39), ('콘텐츠', 3.09)]
# Topic 13: [('추가', 49.58), ('마찬가지', 8.24), ('경험', 6.91), ('지급', 4.92), ('지속', 4.23)]
# Topic 14: [('경험', 224.24), ('스파크', 40.65), ('유료', 40.04), ('기만', 32.76), ('크기', 27.33)]
# Topic 15: [('스파크', 39.83), ('컬쳐', 26.44), ('스타', 20.05), ('경험', 12.84), ('접속', 12.3)]
# Topic 16: [('그동안', 1.62), ('부분', 0.76), ('에러', 0.08), ('콘솔', 0.08), ('일정', 0.08)]
# Topic 17: [('카프카', 14.37), ('신경', 5.67), ('전개', 3.48), ('후회', 2.67), ('하거', 1.34)]
# Topic 18: [('호시노', 58.27), ('버리', 54.86), ('실력', 11.88), ('조각', 9.13), ('혼자', 7.28)]
# Topic 19: [('리니지', 4.95), ('의외', 4.81), ('예약', 4.23), ('건가', 3.5), ('폰타인', 2.39)]
# Topic 20: [('시대', 14.93), ('더빙', 14.75), ('피로', 12.47), ('경험', 10.83), ('이파', 9.54)]
# Topic 21: [('요구', 7.34), ('제한', 2.75), ('아야카', 2.58), ('건지', 2.01), ('위치', 1.93)]
# Topic 22: [('이외', 17.22), ('조사', 5.82), ('중국', 3.29), ('그림', 1.5), ('배경', 1.39)]
# Topic 23: [('유료', 31.71), ('출시', 4.89), ('거부', 4.19), ('다인', 3.85), ('희망', 3.84)]
# Topic 24: [('이상', 25.37), ('오타', 19.15), ('치치', 14.55), ('렙업', 12.04), ('옛날', 10.59)]
# Topic 25: [('보안', 3.72), ('중요', 3.14), ('처리', 2.68), ('친절', 2.4), ('서버', 2.2)]
# Topic 26: [('일본', 14.92), ('경험', 4.76), ('재미', 1.08), ('가슴', 0.98), ('기업', 0.97)]
# Topic 27: [('오타쿠', 17.17), ('숙제', 11.55), ('공격', 5.17), ('사양', 4.96), ('보스', 4.72)]
# Topic 28: [('비교', 3.56), ('원소', 3.31), ('효율', 2.27), ('덩어리', 1.41), ('리셋', 1.38)]
# Topic 29: [('구림', 18.24), ('코드', 9.65), ('호불호', 7.26), ('경험', 5.0), ('따위', 3.93)]
# Topic 30: [('개월', 33.1), ('강제', 9.69), ('경험', 5.95), ('대응', 5.56), ('로딩', 4.13)]
# Topic 1: [('일본', 47.45), ('이해', 10.22), ('선물', 3.07), ('사람', 2.01), ('유료', 2.01)]
# Topic 2: [('정도', 25.72), ('확인', 3.68), ('휴대폰', 2.54), ('공식', 2.13), ('짜증', 1.75)]
# Topic 3: [('참여', 1.67), ('방치', 0.74), ('여행자', 0.26), ('화질', 0.24), ('개발', 0.24)]
# Topic 4: [('얼굴', 19.31), ('건데', 4.75), ('특정', 4.41), ('게임패드', 4.41), ('동일', 3.72)]
# Topic 5: [('테러', 15.0), ('하루', 10.57), ('랜덤', 9.22), ('게임패드', 8.27), ('비교', 7.13)]
# Topic 6: [('기기', 2.3), ('여론', 1.65), ('할만', 1.21), ('이외', 1.01), ('성우', 0.62)]
# Topic 7: [('연출', 5.4), ('반영', 3.26), ('매력', 0.22), ('수록', 0.16), ('과정', 0.15)]
# Topic 8: [('음성', 39.74), ('모델', 3.38), ('방식', 2.77), ('애플리케이션', 2.54), ('다섯', 1.84)]
# Topic 9: [('오류', 9.18), ('개꿀', 8.09), ('복사', 5.7), ('음악', 5.02), ('신박', 4.31)]
# Topic 10: [('오역', 11.14), ('연속', 1.97), ('보통', 1.9), ('취향', 1.32), ('건지', 1.11)]
# Topic 11: [('구글', 20.49), ('문장', 15.46), ('어디', 12.85), ('대신', 9.77), ('평소', 5.95)]
# Topic 12: [('대사', 8.27), ('플레', 6.76), ('표기', 4.03), ('무소', 3.14), ('보임', 2.8)]
# Topic 13: [('울트라', 104.43), ('실력', 61.25), ('게임패드', 58.32), ('보통', 56.99), ('자신', 27.5)]
# Topic 14: [('신규', 27.94), ('부탁', 13.36), ('실력', 4.84), ('연동', 3.89), ('임사', 3.38)]
# Topic 15: [('백도어', 20.48), ('의심', 14.23), ('흥미', 13.9), ('덩어리', 6.97), ('의도', 3.41)]
# Topic 16: [('고려', 10.33), ('설명', 8.48), ('오토', 2.11), ('그대', 1.98), ('유지', 1.8)]
# Topic 17: [('마디', 0.23), ('신뢰', 0.23), ('의심', 0.2), ('그래픽', 0.19), ('오류', 0.15)]
# Topic 18: [('릭터', 2.88), ('호우', 1.87), ('모델링', 1.44), ('종료', 1.25), ('등록', 0.86)]
# Topic 19: [('보통', 147.43), ('주작', 24.61), ('중간', 11.93), ('개발', 8.58), ('평생', 6.84)]
# Topic 20: [('오브', 18.16), ('취급', 15.59), ('보통', 11.53), ('지속', 8.15), ('하드', 6.62)]
# Topic 21: [('인민공화국', 11.43), ('안드로이드', 7.55), ('보통', 3.25), ('메인', 2.32), ('울트라', 0.24)]
# Topic 22: [('게임패드', 64.96), ('보통', 61.46), ('실력', 37.5), ('미션', 31.04), ('한국인', 26.78)]
# Topic 23: [('게임패드', 85.51), ('아이디', 21.47), ('마리안', 20.89), ('성공', 19.01), ('보통', 12.56)]
# Topic 24: [('축하', 1.44), ('보통', 0.33), ('오토', 0.18), ('지장', 0.18), ('공격', 0.15)]
# Topic 25: [('화질', 18.26), ('토리', 13.2), ('스펙', 12.6), ('정상', 8.15), ('지원', 7.05)]
# Topic 26: [('시간', 3.92), ('차지', 1.17), ('다운', 0.3), ('결과', 0.25), ('세상', 0.18)]
# Topic 27: [('픽업', 2.04), ('표시', 1.69), ('센터', 1.21), ('선녀', 0.91), ('가슴', 0.46)]
# Topic 28: [('콘솔', 18.22), ('세계관', 5.26), ('와중', 4.59), ('파티', 3.54), ('게임패드', 2.29)]
# Topic 29: [('마리', 48.74), ('존재', 39.32), ('운영', 17.34), ('선생', 13.86), ('게임패드', 10.99)]
# Topic 30: [('운영', 13.81), ('텐데', 5.96), ('건가요', 4.32), ('나름', 3.72), ('당장', 2.26)]
#
# ::: Topics - Okt :::
# Topic 1: [('리소스', 28.43), ('시로코', 27.87), ('비예', 27.04), ('고생', 9.56), ('대신', 7.94)]
# Topic 2: [('고생', 84.21), ('신경', 74.65), ('끼리', 60.99), ('커녕', 47.44), ('취향', 36.87)]
# Topic 3: [('컨텐츠', 9.42), ('렙업', 5.07), ('이름', 4.57), ('컷씬', 4.08), ('모습', 3.69)]
# Topic 4: [('복각', 3.71), ('간다', 1.87), ('이기', 1.48), ('마침표', 1.47), ('속성', 0.82)]
# Topic 5: [('만약', 4.99), ('종류', 3.29), ('준비', 1.22), ('일차', 0.42), ('클레', 0.39)]
# Topic 6: [('고생', 165.97), ('출석', 12.91), ('한국', 8.26), ('커녕', 7.29), ('최적화', 6.08)]
# Topic 7: [('최소한', 41.47), ('중이', 3.89), ('고생', 3.53), ('시진핑', 1.71), ('중독', 1.42)]
# Topic 8: [('자동', 8.76), ('조각', 5.8), ('대체', 4.36), ('머리', 4.08), ('업데이트', 3.46)]
# Topic 9: [('노잼', 19.47), ('완벽', 7.23), ('여러가지', 3.58), ('조금', 3.57), ('어차피', 2.76)]
# Topic 10: [('관련', 9.31), ('호우', 3.73), ('초보자', 3.17), ('보기', 2.84), ('퀘스트', 1.3)]
# Topic 11: [('기도', 16.5), ('성우', 1.81), ('정리', 1.76), ('저번', 1.54), ('야생', 1.31)]
# Topic 12: [('개추', 22.57), ('엉덩이', 3.82), ('무난', 2.7), ('재밋음', 2.54), ('투성이', 1.81)]
# Topic 13: [('완전', 11.26), ('최신', 10.6), ('옵션', 10.37), ('이틀', 8.49), ('실망', 7.42)]
# Topic 14: [('보상', 28.39), ('스택', 10.99), ('고생', 5.38), ('한정', 4.67), ('상위', 4.52)]
# Topic 15: [('일정', 14.72), ('대한', 3.69), ('비키', 3.53), ('성장', 2.49), ('애초', 2.49)]
# Topic 16: [('마다', 9.39), ('등등', 6.52), ('완벽', 3.18), ('의견', 0.56), ('이점', 0.48)]
# Topic 17: [('오픈', 3.84), ('오지', 3.52), ('충전', 2.72), ('여러분', 2.36), ('바로', 2.18)]
# Topic 18: [('시도', 16.36), ('제작자', 5.52), ('리뷰', 5.47), ('두창', 3.89), ('나름', 2.65)]
# Topic 19: [('일반', 10.51), ('중국산', 4.93), ('인생', 4.69), ('미완료', 4.12), ('실화', 3.56)]
# Topic 20: [('치치', 11.56), ('저장', 3.39), ('자꾸', 2.69), ('하드', 1.46), ('픽뚫', 0.26)]
# Topic 21: [('사이', 22.22), ('도안', 14.4), ('카프카', 9.72), ('학생', 7.15), ('며칠', 6.31)]
# Topic 22: [('제한', 15.91), ('혹시', 8.33), ('몇번', 4.09), ('버스', 3.87), ('평가', 3.4)]
# Topic 23: [('풍경', 3.11), ('역시', 2.47), ('고치', 2.36), ('개발자', 2.17), ('적용', 1.51)]
# Topic 24: [('벌써', 55.66), ('클레', 33.13), ('개판', 30.79), ('예정', 28.35), ('차이', 27.81)]
# Topic 25: [('이미지', 4.52), ('마지막', 2.07), ('주인공', 1.56), ('공식', 1.55), ('해당', 1.54)]
# Topic 26: [('재생', 6.62), ('겨우', 0.8), ('디테일', 0.08), ('고민', 0.08), ('고객', 0.08)]
# Topic 27: [('데이터', 11.97), ('로써', 4.36), ('간다', 3.68), ('검열', 3.6), ('검수', 3.51)]
# Topic 28: [('재밋네', 21.52), ('종료', 8.41), ('금액', 7.83), ('일러스트', 5.71), ('메인', 4.83)]
# Topic 29: [('레이', 33.5), ('실제', 1.88), ('레일', 1.65), ('다음', 1.45), ('불가능', 0.15)]
# Topic 30: [('정지', 13.52), ('게스트', 3.63), ('소리', 1.4), ('다만', 1.15), ('요소', 1.04)]
# Topic 1: [('달리', 20.06), ('회사', 10.84), ('무리', 3.88), ('자꾸', 3.85), ('표시', 3.43)]
# Topic 2: [('그때', 7.91), ('수메르', 6.75), ('달라', 5.83), ('추가', 5.48), ('테러', 4.0)]
# Topic 3: [('마지막', 4.43), ('특성', 3.47), ('환경', 3.42), ('추천', 2.93), ('이상', 2.35)]
# Topic 4: [('강제', 7.73), ('연출', 6.73), ('대사', 6.37), ('가차', 5.13), ('상자', 3.78)]
# Topic 5: [('번역', 20.98), ('음식', 2.23), ('아이', 2.06), ('갑자기', 1.42), ('게이', 0.88)]
# Topic 6: [('어디', 2.29), ('명함', 1.48), ('사과', 1.32), ('라면', 1.14), ('블끼얏', 0.92)]
# Topic 7: [('복귀', 165.68), ('제한', 33.04), ('역시', 19.81), ('게이', 15.72), ('개꿀', 14.38)]
# Topic 8: [('전반', 2.35), ('여러가지', 2.08), ('차별', 1.3), ('여행', 0.56), ('참고', 0.38)]
# Topic 9: [('클레', 5.74), ('시간', 3.78), ('숙제', 1.33), ('개발', 0.48), ('다인', 0.3)]
# Topic 10: [('유출', 36.64), ('알바', 18.87), ('복귀', 16.17), ('로딩', 14.68), ('시로코', 12.46)]
# Topic 11: [('아무', 7.67), ('감사', 4.58), ('제일', 3.34), ('복귀', 2.19), ('민심', 1.71)]
# Topic 12: [('게이', 87.79), ('실망', 55.33), ('복귀', 48.41), ('콘솔', 40.19), ('요즘', 30.58)]
# Topic 13: [('경쟁', 31.27), ('여행', 19.77), ('요소', 17.62), ('게이', 11.66), ('직접', 9.52)]
# Topic 14: [('전략', 17.36), ('확인', 12.59), ('한가지', 12.52), ('복구', 3.16), ('신규', 3.08)]
# Topic 15: [('똑바', 9.87), ('점검', 2.94), ('사건', 2.71), ('된거', 2.32), ('역대', 2.31)]
# Topic 16: [('게이', 64.37), ('신규', 31.49), ('불편', 15.28), ('설치', 12.33), ('접속', 8.73)]
# Topic 17: [('요즘', 71.84), ('카프카', 15.55), ('복귀', 15.46), ('게이', 15.34), ('현재', 10.83)]
# Topic 18: [('좀더', 6.49), ('한게임', 4.35), ('여캐', 3.57), ('더욱', 3.06), ('리세', 2.94)]
# Topic 19: [('홍련', 5.1), ('중이', 3.68), ('공간', 2.53), ('보고', 1.76), ('최고다', 1.06)]
# Topic 20: [('조금', 25.22), ('리얼', 20.26), ('관위', 16.57), ('장르', 6.35), ('복귀', 5.65)]
# Topic 21: [('해주', 2.26), ('비교', 0.69), ('보지', 0.44), ('김용하', 0.2), ('초창', 0.2)]
# Topic 22: [('아이패드', 5.54), ('엉망', 4.72), ('입력', 3.05), ('부담', 0.97), ('부디', 0.77)]
# Topic 23: [('여행자', 18.8), ('성우진', 18.38), ('복귀', 15.33), ('답변', 9.54), ('존재', 8.75)]
# Topic 24: [('다른사람', 41.2), ('지지', 3.01), ('고정', 2.29), ('아이디', 0.73), ('실망', 0.42)]
# Topic 25: [('정액', 33.01), ('개인정보', 23.1), ('실망', 17.76), ('복귀', 14.67), ('미완료', 12.32)]
# Topic 26: [('형태', 2.09), ('방송', 1.59), ('중국', 1.17), ('다른', 0.5), ('다른사람', 0.39)]
# Topic 27: [('본인', 3.56), ('영향', 3.15), ('노트', 2.92), ('소비자', 1.36), ('다만', 1.0)]
# Topic 28: [('퀘스트', 15.3), ('인지', 7.99), ('분량', 3.91), ('항상', 3.76), ('님들', 3.65)]
# Topic 29: [('리셋', 41.11), ('상담', 20.28), ('안고', 16.04), ('게이', 12.16), ('시점', 12.1)]
# Topic 30: [('참고', 27.88), ('음성', 6.92), ('논란', 3.33), ('안나', 2.72), ('게이', 2.56)]

# %%
len(n_k_pos), len(n_k_na)
# Out:
# (5033, 5255)
