# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %%
labels = ['Decision', 'RandomForest', 'KNN']
cnt = [98.36, 98.57, 98.27]
ratio = [89.39, 91.90, 84.28]

# %%
plt.figure(figsize=(12,6))
plt.bar(x=labels, height=cnt)
plt.ylim(9,100)
# Out:
# (96.0, 100.0)
