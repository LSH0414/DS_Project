# %% [markdown]
# # KBO 팀 데이터 EDA

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import sys
sys.path.append(os.path.dirname(os.path.abspath(os.path.dirname('set_matplotlib_hangul.py'))))

pd.set_option('display.max_column',100)
pd.set_option('display.max_row',500)
import warnings
warnings.filterwarnings("ignore")

# %%
kbo_df = pd.read_csv('./data/kbopitchingdata.csv')

kbo_df.head()
# Out:
#    id  year           team  average_age  runs_per_game  wins  losses  \
# 0   1  2021       LG Twins         26.3           3.90    72      57
# 1   2  2021         KT Wiz         28.4           4.06    75      59
# 2   3  2021   Doosan Bears         27.5           4.57    70      65
# 3   4  2021  Samsung Lions         28.8           4.57    75      59
# 4   5  2021       NC Dinos         27.7           4.80    67      67
#
#    win_loss_percentage   ERA  run_average_9  games  games_started  \
# 0                0.558  3.57           3.96    143          143.0
# 1                0.560  3.67           4.17    143          143.0
# 2                0.519  4.28           4.66    143          143.0
# 3                0.560  4.29           4.70    143          143.0
# 4                0.500  4.50           4.95    143          143.0
#
#    games_finished  complete_game  shutouts  saves  innings_pitched  hits  \
# 0           143.0              0        18     32           1264.1  1117
# 1           141.0              2         6     33           1255.0  1166
# 2           141.0              2        10     27           1260.1  1288
# 3           141.0              2        14     46           1250.0  1287
# 4           140.0              3        10     33           1247.2  1256
#
#    runs  earned_runs  home_runs  walks  intentional_walks  strikeouts  \
# 0   557          501         79    542               17.0        1062
# 1   581          512         85    486               18.0        1051
# 2   653          599        104    586               16.0        1037
# 3   653          596        129    526               13.0        1031
# 4   686          624        122    585               14.0        1046
#
#    hit_batter  balks  wild_pitches  batters_faced   WHIP  hits_9  homeruns_9  \
# 0          97    5.0          43.0           5416  1.312     8.0         0.6
# 1          42    1.0          56.0           5359  1.316     8.4         0.6
# 2          73    7.0          51.0           5596  1.487     9.2         0.7
# 3          51    3.0          56.0           5496  1.450     9.3         0.9
# 4          77    8.0          74.0           5575  1.476     9.1         0.9
#
#    walks_9  strikeouts_9  strikeout_walk
# 0      3.9           7.6            1.96
# 1      3.5           7.5            2.16
# 2      4.2           7.4            1.77
# 3      3.8           7.4            1.96
# 4      4.2           7.5            1.79

# %%
kbo_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 323 entries, 0 to 322
# Data columns (total 34 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   323 non-null    int64
#  1   year                 323 non-null    int64
#  2   team                 323 non-null    object
#  3   average_age          323 non-null    float64
#  4   runs_per_game        323 non-null    float64
#  5   wins                 323 non-null    int64
#  6   losses               323 non-null    int64
#  7   win_loss_percentage  323 non-null    float64
#  8   ERA                  323 non-null    float64
#  9   run_average_9        323 non-null    float64
#  10  games                323 non-null    int64
#  11  games_started        184 non-null    float64
#  12  games_finished       184 non-null    float64
#  13  complete_game        323 non-null    int64
#  14  shutouts             323 non-null    int64
#  15  saves                323 non-null    int64
#  16  innings_pitched      323 non-null    float64
#  17  hits                 323 non-null    int64
#  18  runs                 323 non-null    int64
#  19  earned_runs          323 non-null    int64
#  20  home_runs            323 non-null    int64
#  21  walks                323 non-null    int64
#  22  intentional_walks    184 non-null    float64
#  23  strikeouts           323 non-null    int64
#  24  hit_batter           323 non-null    int64
#  25  balks                184 non-null    float64
#  26  wild_pitches         184 non-null    float64
#  27  batters_faced        323 non-null    int64
#  28  WHIP                 323 non-null    float64
#  29  hits_9               323 non-null    float64
#  30  homeruns_9           323 non-null    float64
#  31  walks_9              323 non-null    float64
#  32  strikeouts_9         323 non-null    float64
#  33  strikeout_walk       323 non-null    float64
# dtypes: float64(17), int64(16), object(1)
# memory usage: 85.9+ KB

# %%
kbo_df.columns
# Out:
# Index(['id', 'year', 'team', 'average_age', 'runs_per_game', 'wins', 'losses',
#        'win_loss_percentage', 'ERA', 'run_average_9', 'games', 'games_started',
#        'games_finished', 'complete_game', 'shutouts', 'saves',
#        'innings_pitched', 'hits', 'runs', 'earned_runs', 'home_runs', 'walks',
#        'intentional_walks', 'strikeouts', 'hit_batter', 'balks',
#        'wild_pitches', 'batters_faced', 'WHIP', 'hits_9', 'homeruns_9',
#        'walks_9', 'strikeouts_9', 'strikeout_walk'],
#       dtype='object')

# %%
kbo_df.isnull().sum()
# Out:
# id                       0
# year                     0
# team                     0
# average_age              0
# runs_per_game            0
# wins                     0
# losses                   0
# win_loss_percentage      0
# ERA                      0
# run_average_9            0
# games                    0
# games_started          139
# games_finished         139
# complete_game            0
# shutouts                 0
# saves                    0
# innings_pitched          0
# hits                     0
# runs                     0
# earned_runs              0
# home_runs                0
# walks                    0
# intentional_walks      139
# strikeouts               0
# hit_batter               0
# balks                  139
# wild_pitches           139
# batters_faced            0
# WHIP                     0
# hits_9                   0
# homeruns_9               0
# walks_9                  0
# strikeouts_9             0
# strikeout_walk           0
# dtype: int64

# %% [markdown]
# ## EDA

# %% [markdown]
# #### Team Data

# %%
kbo_df['team'].unique()
# Out:
# array(['LG Twins', 'KT Wiz', 'Doosan Bears', 'Samsung Lions', 'NC Dinos',
#        'Kiwoom Heroes', 'SSG Landers', 'Hanwha Eagles', 'Kia Tigers',
#        'Lotte Giants', 'SK Wyverns', 'Nexen Heroes', 'Woori Heroes',
#        'Hyundai Unicorns', 'Haitai Tigers', 'Ssangbangwool Raiders',
#        'OB Bears', 'Pacific Dolphins', 'Binggre Eagles',
#        'MBC Blue Dragons', 'Chungbo Pintos', 'Sammi Superstars'],
#       dtype=object)

# %%
teams = kbo_df['team'].unique()

# %%
plt.figure(figsize=(60,30), dpi=80)
sns.lineplot(data = kbo_df, x='year', y='win_loss_percentage', hue='team')
plt.legend(labels=teams, loc=2, bbox_to_anchor = (0,0), prop={'size':30})
plt.show()

# %% [markdown]
# 그래프를 보면 처음부터 끝까지 이어지는 팀이 있는 반면 중간에 끊어지거나 중간에 새로 생긴 팀(라인)이 있다.
# 데이터 포함된 기간중 사라지고 새로생긴 팀들의 년도와 같이 확인해보자

# %%
kbo_df['year'].describe()
# Out:
# count     323.000000
# mean     2002.944272
# std        11.501957
# min      1982.000000
# 25%      1993.000000
# 50%      2003.000000
# 75%      2013.000000
# max      2021.000000
# Name: year, dtype: float64

# %%
team_df = kbo_df[['year','win_loss_percentage','team']].groupby(['team','year']).count().reset_index()

boom_team = {y : [] for y in range(1982,2022)}
build_team = {y : [] for y in range(1982,2022)}

for y in range(1982,2022):
    year_teams_list = team_df[team_df['year']==y]['team'].tolist()
    # print("{:4} 년 kbo 소속 팀 리스트 : {} " .format(y, year_teams_list))
    try:
        if set(year_teams_list) != set(before_teams_list):
            # print("In {} year Any team(s) build or boom!!" .format(y))
            # print("*"*50)
            # print('Build Team(s) : ', set(year_teams_list) - set(before_teams_list))
            # print('Boom Team(s) : ', set(before_teams_list) - set(year_teams_list))
            # print("*"*50,"\n")
            if len(set(year_teams_list) - set(before_teams_list)) != 0:
                build_team[y] = list(set(year_teams_list) - set(before_teams_list))
            if len(set(before_teams_list) - set(year_teams_list)) !=0:
                boom_team[y-1] = list(set(before_teams_list) - set(year_teams_list))
    except Exception as e:
        print("Maybe Now 1st KBO SEASON...")

    before_teams_list = year_teams_list.copy()

# %%
print('\n---- Build Tema Historty ----')
for idx, bt in build_team.items():
    if len(bt) != 0 :
        print("{} build team(s) : {}" . format(idx, bt))
# Out:
# ---- Build Tema Historty ----
# 1982 build team(s) : ['Haitai Tigers', 'Sammi Superstars', 'MBC Blue Dragons', 'OB Bears']
# 1985 build team(s) : ['Chungbo Pintos']
# 1986 build team(s) : ['Binggre Eagles']
# 1988 build team(s) : ['Pacific Dolphins']
# 1990 build team(s) : ['LG Twins']
# 1991 build team(s) : ['Ssangbangwool Raiders']
# 1994 build team(s) : ['Hanwha Eagles']
# 1996 build team(s) : ['Hyundai Unicorns']
# 1999 build team(s) : ['Doosan Bears']
# 2000 build team(s) : ['SK Wyverns']
# 2001 build team(s) : ['Kia Tigers']
# 2008 build team(s) : ['Woori Heroes']
# 2010 build team(s) : ['Nexen Heroes']
# 2013 build team(s) : ['NC Dinos']
# 2015 build team(s) : ['KT Wiz']
# 2019 build team(s) : ['Kiwoom Heroes']
# 2021 build team(s) : ['SSG Landers']

# %%
print('\n---- 팀 해체와 창설 수가 다른 시즌 ----')
for idx, bt in boom_team.items():
    if idx ==2021:break
    if len(bt) != len(build_team[idx+1]):
        print("{} boom team(s) : {}" .format(idx, bt))
        print("{} build team(s) : {}\n" .format(idx+1, build_team[idx+1]))
# Out:
# ---- 팀 해체와 창설 수가 다른 시즌 ----
# 1985 boom team(s) : []
# 1986 build team(s) : ['Binggre Eagles']
#
# 1990 boom team(s) : []
# 1991 build team(s) : ['Ssangbangwool Raiders']
#
# 2012 boom team(s) : []
# 2013 build team(s) : ['NC Dinos']
#
# 2014 boom team(s) : []
# 2015 build team(s) : ['KT Wiz']

# %%
print('\n---- 팀 해체 후 다음 시즌 창설된 팀 ----')
for idx, bt in boom_team.items():
    if idx ==2021:break
    if len(bt) != 0 :
        print("{} boom team(s) : {}" .format(idx, bt))
        print("{} build team(s) : {}\n" .format(idx+1, build_team[idx+1]))
# Out:
# ---- 팀 해체 후 다음 시즌 창설된 팀 ----
# 1984 boom team(s) : ['Sammi Superstars']
# 1985 build team(s) : ['Chungbo Pintos']
#
# 1987 boom team(s) : ['Chungbo Pintos']
# 1988 build team(s) : ['Pacific Dolphins']
#
# 1989 boom team(s) : ['MBC Blue Dragons']
# 1990 build team(s) : ['LG Twins']
#
# 1993 boom team(s) : ['Binggre Eagles']
# 1994 build team(s) : ['Hanwha Eagles']
#
# 1995 boom team(s) : ['Pacific Dolphins']
# 1996 build team(s) : ['Hyundai Unicorns']
#
# 1998 boom team(s) : ['OB Bears']
# 1999 build team(s) : ['Doosan Bears']
#
# 1999 boom team(s) : ['Ssangbangwool Raiders']
# 2000 build team(s) : ['SK Wyverns']
#
# 2000 boom team(s) : ['Haitai Tigers']
# 2001 build team(s) : ['Kia Tigers']
#
# 2007 boom team(s) : ['Hyundai Unicorns']
# 2008 build team(s) : ['Woori Heroes']
#
# 2009 boom team(s) : ['Woori Heroes']
# 2010 build team(s) : ['Nexen Heroes']
#
# 2018 boom team(s) : ['Nexen Heroes']
# 2019 build team(s) : ['Kiwoom Heroes']
#
# 2020 boom team(s) : ['SK Wyverns']
# 2021 build team(s) : ['SSG Landers']

# %% [markdown]
# ```
# 팀 해체 한 후 창설된 팀이 각각 매칭 되는 것으로 보아 스폰서가 바뀌면서 팀명이 변경 됐다고 보는 것에 무리가 없어 보인다.
# 그 이유로는
# 1. 각 팀이 해체 된 이후 다음 시즌에 창설된 팀이 1개로 각각 매칭 된다는점.
# 2. 해체 된 팀의 수와 창설된 팀의 수가 다른 시즌을 확인해본 결과 완전 새롭게 창설된 팀들만 존재하는 것을 확인.
#
# 위와 같은 이유로 두 팀이 이어져있다고 봐도 무방하다고 생각되어 이 리스트에 있는 팀들을 현재 운영중인 팀으로 하나의 팀으로 이어서 그래프를 다시 그려보기로 하였다.
# ```

# %% [markdown]
# [310, 312, 322]

# %%
cnt = 1
for idx, bt in boom_team.items():
    if idx ==2021:break
    if len(bt) != 0 :
        kbo_df.replace(bt[0], build_team[idx+1][0], inplace=True)
        print("{:2}. ".format(cnt) ,bt[0], " ->", build_team[idx+1][0])
        cnt+=1
# Out:
#  1.  Sammi Superstars  -> Chungbo Pintos
#  2.  Chungbo Pintos  -> Pacific Dolphins
#  3.  MBC Blue Dragons  -> LG Twins
#  4.  Binggre Eagles  -> Hanwha Eagles
#  5.  Pacific Dolphins  -> Hyundai Unicorns
#  6.  OB Bears  -> Doosan Bears
#  7.  Ssangbangwool Raiders  -> SK Wyverns
#  8.  Haitai Tigers  -> Kia Tigers
#  9.  Hyundai Unicorns  -> Woori Heroes
# 10.  Woori Heroes  -> Nexen Heroes
# 11.  Nexen Heroes  -> Kiwoom Heroes
# 12.  SK Wyverns  -> SSG Landers

# %%
kbo_df['team'].unique(),  len(kbo_df['team'].unique())
# Out:
# (array(['LG Twins', 'KT Wiz', 'Doosan Bears', 'Samsung Lions', 'NC Dinos',
#         'Kiwoom Heroes', 'SSG Landers', 'Hanwha Eagles', 'Kia Tigers',
#         'Lotte Giants'], dtype=object),
#  10)

# %%
teams = kbo_df['team'].unique()

plt.figure(figsize=(60,30), dpi=80)
sns.lineplot(data = kbo_df, x='year', y='win_loss_percentage', hue='team')
plt.legend(labels=teams, loc=2, bbox_to_anchor = (0,0), prop={'size':30})
plt.show()

# %% [markdown]
# ### 팀 명 입력시 년도별 팀 평균 데이터 출력해주기

# %%
# 키워드만 입력해도 팀 풀네임 찾아주기
def findTeamFullName(keyword):
    user_keyword = keyword

    return kbo_df[kbo_df['team'].str.contains(user_keyword)]['team'].unique()[0]

# %%
findTeamFullName('Eagles'), findTeamFullName('KT')
# Out:
# ('Hanwha Eagles', 'KT Wiz')

# %%
kbo_df.columns
# Out:
# Index(['id', 'year', 'team', 'average_age', 'runs_per_game', 'wins', 'losses',
#        'win_loss_percentage', 'ERA', 'run_average_9', 'games', 'games_started',
#        'games_finished', 'complete_game', 'shutouts', 'saves',
#        'innings_pitched', 'hits', 'runs', 'earned_runs', 'home_runs', 'walks',
#        'intentional_walks', 'strikeouts', 'hit_batter', 'balks',
#        'wild_pitches', 'batters_faced', 'WHIP', 'hits_9', 'homeruns_9',
#        'walks_9', 'strikeouts_9', 'strikeout_walk'],
#       dtype='object')

# %%
def printStaticInfo(team_df, col):

# %%
def drawAvgPlot(team_df, col):
    
    sns.lineplot(data = team_df, x='year', y=col).set(title = col + 'AVG Graphs of year')
    printStaticInfo(team_df, col)

# %%
def drawAvgTeamData(team):
    team_df = kbo_df[kbo_df['team']==team]

    cols = ['average_age', 'runs_per_game', 'wins', 'losses',
       'win_loss_percentage', 'ERA', 'run_average_9']
    
    for col in cols:
        plt.figure(figsize=(12,6))
        drawAvgPlot(team_df, col)
        plt.show()

# %%
drawAvgTeamData(findTeamFullName('Eagles'))
